# %%
#Importando las librerias necesarias
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wave
import pylab
from pathlib import Path
from scipy import signal
from scipy.io import wavfile
from sklearn.metrics import confusion_matrix
import random
import itertools
#----------------
import sys
#----------------
import time

import os

# %% [markdown]
# ---
# ##removeBack_clipped_balanced
#
# ---
#
#
#
# Traatando de concontrar los mejores modelos
#
#
# ---
#
# SCIKITMAAD

# %%
# Check nvidia and nvcc cuda compiler

# !nvidia-smi
# !/usr/local/cuda/bin/nvcc --version
#import os
#from tensorflow.python.profiler import profiler_client

#tpu_profile_service_address = os.environ['COLAB_TPU_ADDR'].replace('8470', '8466')
#print(profiler_client.monitor(tpu_profile_service_address, 100, 2))
# Out:
# Mon Mar 27 19:20:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %% [markdown]
# # 1.- GET DATA
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Loading the dataset: birdsBolivia
#
# ---

# %%
# El dataset es cargado en DRIVE, se definen los directorios de lectura de los archivos de audio y escritura de los espectogramas generados
# Previamente debe estar montada la unidad de drive en colab
WAVES_DIR       = '/content/drive/MyDrive/Thesis/DataSets/BirdsBolivia/audio/recordings_clipped/'  #'/content/drive/MyDrive/Thesis/test/'
#spectrogramas scikit maad
SPECTOGRAMS_DIR = '/content/drive/MyDrive/Thesis/DataSets/BirdsBolivia/images/spect_clipped_removeback_balanced/'
#SPECTOGRAMS_DIR = '/content/drive/My Drive/DataSets/FreeSpokenDigitDataset/spectrograms_pylab/'

# %%
#cargando el listado de archivos de audio
waves = os.listdir(WAVES_DIR)
#sampling_rate: frecuencia de muestreo es el número de esas muestras del audio que hay en un 1 segundo.
# 44100 es un standar basado en la teoria de Nyquist
# 22050  tambien es aceptable aunque se perderian algunas frecuencias altas, es el mas usado 
#sampling_rate = 22050
waves
# Out:
# ['2', '3', '4', '5', '6', '8', '9', '10', '1', '7']

# %% [markdown]
# ##Print all the classes/categories that we have for the target
#
# ---

# %%
import os
print('root:'+SPECTOGRAMS_DIR)
for root, dirs, files in os.walk(SPECTOGRAMS_DIR, topdown=False):   
   #for name in files:
      #print(os.path.join(root, name))       
   for name in dirs:
      #print(os.path.join(root, name)) 
      #print('Clase: '+ name)
      initial_count = 0
      dir = os.path.join(root, name)
      for path in os.listdir(dir):
        if os.path.isfile(os.path.join(dir, path)):
          initial_count += 1
      print('Clase: '+ name+' ; '+'Qty files:'+str(initial_count))
# Out:
# root:/content/drive/MyDrive/Thesis/DataSets/BirdsBolivia/images/spect_clipped_removeback_balanced/
# Clase: bird2 ; Qty files:300
# Clase: bird1 ; Qty files:300
# Clase: bird3 ; Qty files:300
# Clase: bird4 ; Qty files:300
# Clase: bird5 ; Qty files:300
# Clase: bird6 ; Qty files:300
# Clase: bird8 ; Qty files:300
# Clase: bird9 ; Qty files:300
# Clase: bird10 ; Qty files:300
# Clase: bird7 ; Qty files:300

# %% [markdown]
# #Preparing the data
#
# ---
# Vamos a usar TensorFlow para generar un tf.data.Dataset a partir de archivos de imagen en un directorio.
# TensorFlow es un paquete de DeepLearning desarrollado y de código abierto por Google.
#
# Luego, llamar a image_dataset_from_directory(main_directory, labels='inferred') devolverá un tf.data.Dataset que produce lotes de imágenes de los subdirectorios class_a y class_b, etc , junto con las etiquetas 0 y 1 , etc. (0 correspondiente a class_a y 1 correspondiente a class_b ).
#
# Formatos de imagen soportados:jpeg,png,bmp,gif.Los gifs animados se truncan hasta el primer fotograma
#
# Ahora podemos cargar los espectrogramas en la memoria. Usamos la utilidad image_dataset_from_directory para generar los conjuntos de datos, y usamos las capas de preprocesamiento de imágenes de Keras para la estandarización de imágenes y el aumento de datos. El conjunto de validación es lo que en última instancia será nuestro punto de referencia cuando se trata del rendimiento y la precisión de nuestro clasificador. El tamaño del lote es bastante bajo por ahora (32) para que todas las imágenes quepan en la memoria. La semilla es para la reproducibilidad.
#
# More information:
#
# https://keras.io/examples/vision/image_classification_from_scratch/
# https://runebook.dev/es/docs/tensorflow/keras/preprocessing/image_dataset_from_directory
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

# %%
import tensorflow as tf
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
# Declare constants
IMAGE_HEIGHT = 256
IMAGE_WIDTH = 256
NO_CHANNELS = 3
###################################################
# PARAMETRIZAR  NRO CLASES
###################################################
NO_CLASSES = 10
###################################################
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, NO_CHANNELS)
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                          directory=SPECTOGRAMS_DIR,#Directorio raiz
                          labels='inferred',#si se utiliza inferred produce lotes de imágenes de los subdirectorios, cada debe existir un directorio por cada clase 
                          label_mode='int', # va a codificar el label  como labelEncode  1 2 3 etc # 'categorical' codifica como  one hot encode
                          image_size=(IMAGE_HEIGHT, IMAGE_WIDTH), #Tamaño para cambiar el tamaño de las imágenes después de leerlas del disco
                          interpolation='bilinear', #el método de interpolación utilizado al cambiar el tamaño de las imágenes. El valor predeterminado es bilineal.
                          batch_size=32, # Tamaño de  los lotes de datos, es decir va a tomar cada 32 registros
                          shuffle=True, # Para mezclar los datos
                          color_mode='rgb',# Para determinar cuantos canales va a tener la imagen "grayscale", "rgb", "rgba"
                          validation_split=0.2,# Fraccion de datos que se va a reservar para validacion
                          subset="training", # Solo se usa si el validation_split esta configurado, especifica que dataset va a retornar  
                          seed=0
                          )
valid_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                          directory=SPECTOGRAMS_DIR, # directorio raiz
                          labels='inferred', #   
                          label_mode='int',  #
                          image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                          interpolation='bilinear',
                          batch_size=32,
                          shuffle=True,
                          color_mode='rgb',
                          validation_split=0.2,
                          subset="validation",
                          seed=0
                          )
# Out:
# Found 3000 files belonging to 10 classes.
# Using 2400 files for training.
# Found 3000 files belonging to 10 classes.
# Using 600 files for validation.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
train_dataset.class_names
# Out:
# ['bird1',
#  'bird10',
#  'bird2',
#  'bird3',
#  'bird4',
#  'bird5',
#  'bird6',
#  'bird7',
#  'bird8',
#  'bird9']

# %% [markdown]
# #Reviewing a little the dataser generated
#
# ---

# %%
train_dataset.take(1)
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
#ds_train_.take(1)

# %%
### se puede ver el tensor de 32
## Cada registro representa una etiqueta, como se ha utilizado label mode=int, cada categoria esta  codificada como label encode numero en la misma columna
## es posible cambiar esto usando "categorial" en ese caso se geneera un tensor de 32, donde cada item es un array a suvez en codificacion one hote
for images, labels in train_dataset.take(1):
    print(labels)
# Out:
# tf.Tensor([1 7 6 3 7 2 9 5 9 6 5 5 0 6 9 8 9 6 1 2 9 0 3 5 3 1 7 3 3 7 2 7], shape=(32,), dtype=int32)

# %%
### revisando la data, vemos que las imagenes estan como tensores
for images, labels in train_dataset.take(1):
    print(images)
# Out:
# tf.Tensor(
# [[[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]]], shape=(32, 256, 256, 3), dtype=float32)

# %%
### ploteando las imagenes desde los arreglos, el primer bacth de 32
plt.figure(figsize=(4, 4))
for images, labels in train_dataset.take(1):
    for i in range(32): 
        ax = plt.subplot(4, 8, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")    
plt.show()

# %% [markdown]
# #Scaling
#
# ---
# I applied a rescaling the data input from the (0, 255) range to be in the (0,1) range.

# %%
rescale = Rescaling(scale=1.0/255)
train_esc = train_dataset.map(lambda image,label:(rescale(image),label))
valid_esc  = valid_dataset.map(lambda image,label:(rescale(image),label))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# #MODELING
#
# ---

# %%
# !pip install pad_sequences
# !pip install Keras-Preprocessing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pad_sequences in /usr/local/lib/python3.9/dist-packages (0.6.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Keras-Preprocessing in /usr/local/lib/python3.9/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from Keras-Preprocessing) (1.22.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from Keras-Preprocessing) (1.16.0)

# %%
from keras.layers import Dense, Softmax, Dropout

# %%
from keras.callbacks import ModelCheckpoint
#from keras.preprocessing.sequence import pad_sequences
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GRU
from keras.layers import Activation, Dropout, Flatten, Dense, TimeDistributed

# %%
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, NO_CHANNELS)

# %%
#NO_CLASSES = 10

# %% [markdown]
# # Model#1 : CNN1-DROPOUT
#
# ---

# %%
# Create CNN model #1 
#las capas convolucinales extraen features de las imagenes
# las unidades de las redes neuronales se definen  con pequeños valores, por que cuando usamos 256 ,128,64  kicks ERROR :(  problemas de memoria
cnn1 = Sequential()
cnn1.add(Conv2D(16,kernel_size=(3, 3),activation="relu", padding='valid' ,input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NO_CHANNELS)))
cnn1.add(MaxPooling2D((2, 2), strides=2))
cnn1.add(Dropout(0.5))
cnn1.add(Conv2D(32, kernel_size=(3, 3),activation="relu", padding='valid' ))
cnn1.add(MaxPooling2D((2, 2),strides=2))
cnn1.add(Dropout(0.5))
cnn1.add(Conv2D(64, kernel_size=(3, 3),activation="relu", padding='valid' ))
cnn1.add(MaxPooling2D((2, 2),strides=2))
cnn1.add(Dropout(0.5))
cnn1.add(Conv2D(128, kernel_size=(3, 3),activation="relu", padding='valid' ))
cnn1.add(MaxPooling2D((2, 2),strides=2))
cnn1.add(Dropout(0.5))
#capa de clasisficacion
cnn1.add(Flatten())
cnn1.add(Dense(32,activation="relu"))
cnn1.add(Dense(NO_CLASSES, activation="softmax"))

cnn1.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_136 (Conv2D)         (None, 254, 254, 16)      448
#
#  max_pooling2d_61 (MaxPoolin  (None, 127, 127, 16)     0
#  g2D)
#
#  dropout_36 (Dropout)        (None, 127, 127, 16)      0
#
#  conv2d_137 (Conv2D)         (None, 125, 125, 32)      4640
#
#  max_pooling2d_62 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  dropout_37 (Dropout)        (None, 62, 62, 32)        0
#
#  conv2d_138 (Conv2D)         (None, 60, 60, 64)        18496
#
#  max_pooling2d_63 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  dropout_38 (Dropout)        (None, 30, 30, 64)        0
#
#  conv2d_139 (Conv2D)         (None, 28, 28, 128)       73856
#
#  max_pooling2d_64 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  dropout_39 (Dropout)        (None, 14, 14, 128)       0
#
#  flatten_17 (Flatten)        (None, 25088)             0
#
#  dense_58 (Dense)            (None, 32)                802848
#
#  dense_59 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 900,618
# Trainable params: 900,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
cnn1.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy'],
)

# %%
import time
start1 = time.time()
# Train model for 10 epochs, capture the history
cnn1_hist = cnn1.fit(train_esc, epochs=75, validation_data=valid_esc)
end1 = time.time()
cnn1_time = end1-start1
print("CNN #1 Time: {:0.2f} minute".format(cnn1_time/60.0))
# Out:
# Epoch 1/75
# 75/75 [==============================] - 5s 31ms/step - loss: 2.2949 - accuracy: 0.1154 - val_loss: 2.2925 - val_accuracy: 0.1733
# Epoch 2/75
# 75/75 [==============================] - 3s 34ms/step - loss: 2.1699 - accuracy: 0.1917 - val_loss: 2.1093 - val_accuracy: 0.2450
# Epoch 3/75
# 75/75 [==============================] - 3s 35ms/step - loss: 1.8469 - accuracy: 0.3233 - val_loss: 1.8270 - val_accuracy: 0.3550
# Epoch 4/75
# 75/75 [==============================] - 3s 35ms/step - loss: 1.5375 - accuracy: 0.4187 - val_loss: 1.5113 - val_accuracy: 0.4133
# Epoch 5/75
# 75/75 [==============================] - 3s 34ms/step - loss: 1.3004 - accuracy: 0.4825 - val_loss: 1.3174 - val_accuracy: 0.4917
# Epoch 6/75
# 75/75 [==============================] - 3s 34ms/step - loss: 1.1385 - accuracy: 0.5117 - val_loss: 1.1931 - val_accuracy: 0.5217
# Epoch 7/75
# 75/75 [==============================] - 3s 34ms/step - loss: 1.0254 - accuracy: 0.5813 - val_loss: 1.0713 - val_accuracy: 0.5617
# Epoch 8/75
# 75/75 [==============================] - 3s 35ms/step - loss: 0.9343 - accuracy: 0.6117 - val_loss: 0.9910 - val_accuracy: 0.5533
# Epoch 9/75
# 75/75 [==============================] - 3s 35ms/step - loss: 0.8653 - accuracy: 0.6383 - val_loss: 0.9974 - val_accuracy: 0.5517
# Epoch 10/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.8148 - accuracy: 0.6425 - val_loss: 0.8803 - val_accuracy: 0.5867
# Epoch 11/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.7293 - accuracy: 0.6675 - val_loss: 0.8617 - val_accuracy: 0.5967
# Epoch 12/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.7083 - accuracy: 0.6792 - val_loss: 0.8819 - val_accuracy: 0.5650
# Epoch 13/75
# 75/75 [==============================] - 3s 37ms/step - loss: 0.6675 - accuracy: 0.6925 - val_loss: 0.8645 - val_accuracy: 0.5983
# Epoch 14/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.6546 - accuracy: 0.6963 - val_loss: 0.8469 - val_accuracy: 0.5683
# Epoch 15/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.5974 - accuracy: 0.7067 - val_loss: 0.8209 - val_accuracy: 0.5850
# Epoch 16/75
# 75/75 [==============================] - 3s 33ms/step - loss: 0.3343 - accuracy: 0.7921 - val_loss: 0.8626 - val_accuracy: 0.6100
# Epoch 75/75
# 75/75 [==============================] - 3s 34ms/step - loss: 0.3324 - accuracy: 0.7937 - val_loss: 0.9120 - val_accuracy: 0.6150
# CNN #1 Time: 3.61 minute

# %% [markdown]
#  ***** Generating evaluation metrics CNN1 ****
#
#  Asignamos los resultados de model.fit a un objeto history. Esto nos permitirá ver los resultados de las pruebas

# %%
# cm is the confusion matrix, names are the names of the classes.
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=90)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn1.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
# Out:
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 104ms/step

# %%
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN1 Summary---------------")
print("--------------------------------------------")
print("CNN1 Time: {:0.2f} minute".format(cnn1_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# --------------------------------------------
# -----------------CNN1 Summary---------------
# --------------------------------------------
# CNN1 Time: 3.61 minute
# F1 score: 0.5922267271649352
# Accuracy score: 0.615
# Precision score: 0.615
# Recall score: 0.615

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(cnn1_hist.history['accuracy'])
plt.plot(cnn1_hist.history['val_accuracy'])
plt.title('CNN1 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(cnn1_hist.history['loss'])
plt.plot(cnn1_hist.history['val_loss'])
plt.title('CNN1 : Loss function')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
#cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
#cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("--------- Plotting confusion matrix--------")
print("-------------------------------------------")
#print("CNN2 Trainning Time: {:0.2f} minute".format(cnn2_time/60.0))
#print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN1 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred))
# Out:
# -------------------------------------------
# --------- Plotting confusion matrix--------
# -------------------------------------------
# ------------------------------------------------------------
# ----------------- Classification Report CNN1 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.87      0.53        52
#          1.0       0.81      0.81      0.81        52
#          2.0       0.30      0.04      0.08        69
#          3.0       0.83      0.65      0.73        60
#          4.0       0.99      0.96      0.97        69
#          5.0       0.15      0.11      0.12        55
#          6.0       0.72      0.81      0.76        68
#          7.0       0.84      0.73      0.78        59
#          8.0       0.29      0.37      0.32        54
#          9.0       0.72      0.81      0.76        62
#
#     accuracy                           0.61       600
#    macro avg       0.60      0.61      0.59       600
# weighted avg       0.61      0.61      0.59       600

# %% [markdown]
# # Model#2
#
# ---

# %%
import keras
#from keras.models import Sequential,Input,Model
from tensorflow.keras.layers import Input
#from tensorflow.keras.layers import Input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers.advanced_activations import LeakyReLU
from keras.layers import ELU, PReLU, LeakyReLU
from keras.layers import LeakyReLU
import tensorflow as tf 
INIT_LR = 1e-3
#epochs = 10
batch_size = 64

# %%
cnn2 = Sequential()
cnn2.add(Conv2D(32, kernel_size=(3, 3),strides=1,activation='linear',input_shape=(256,256,3)))
cnn2.add(LeakyReLU(alpha=0.1))
cnn2.add(Dropout(0.5))
cnn2.add(Conv2D(64, kernel_size=(3, 3),strides=1, activation='linear'))
cnn2.add(Dropout(0.5))
cnn2.add(LeakyReLU(alpha=0.1))
cnn2.add(Conv2D(128, kernel_size=(3, 3),strides=2,activation='linear'))
cnn2.add(LeakyReLU(alpha=0.1))
cnn2.add(MaxPooling2D((2, 2),strides=2))
cnn2.add(Dropout(0.5))


cnn2.add(Flatten())
cnn2.add(Dense(128, activation='selu'))
cnn2.add(Dense(64, activation='selu'))
cnn2.add(Dense(32, activation='selu'))
cnn2.add(Dropout(0.5)) 
cnn2.add(Dense(NO_CLASSES, activation='softmax',kernel_initializer='lecun_normal'))
 
cnn2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 254, 254, 32)      896
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 254, 254, 32)      0
#
#  dropout_32 (Dropout)        (None, 254, 254, 32)      0
#
#  conv2d_43 (Conv2D)          (None, 252, 252, 64)      18496
#
#  dropout_33 (Dropout)        (None, 252, 252, 64)      0
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 252, 252, 64)      0
#
#  conv2d_44 (Conv2D)          (None, 125, 125, 128)     73856
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 125, 125, 128)     0
#
#  max_pooling2d_21 (MaxPoolin  (None, 62, 62, 128)      0
#  g2D)
#
#  dropout_34 (Dropout)        (None, 62, 62, 128)       0
#
#  flatten_9 (Flatten)         (None, 492032)            0
#
#  dense_19 (Dense)            (None, 128)               62980224
#
#  dense_20 (Dense)            (None, 64)                8256
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dropout_35 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 63,084,138
# Trainable params: 63,084,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn2.compile(
      loss=keras.losses.sparse_categorical_crossentropy, 
      optimizer=tf.keras.optimizers.legacy.Adagrad(learning_rate=INIT_LR, decay=INIT_LR / 100)
      ,metrics=['accuracy']
)

#cnn2.compile(optimizers.rmsprop(lr=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])

# %%
import time
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn2 = cnn2.fit(train_esc, epochs=80, validation_data=valid_esc)
end1 = time.time()
cnn2_time = end1-start1
print("CNN #2 Time: {:0.2f} minute".format(cnn2_time/60.0))
# Out:
# Epoch 1/80
# 75/75 [==============================] - 6s 63ms/step - loss: 2.6614 - accuracy: 0.1388 - val_loss: 2.2455 - val_accuracy: 0.1767
# Epoch 2/80
# 75/75 [==============================] - 5s 61ms/step - loss: 2.2214 - accuracy: 0.1950 - val_loss: 2.2033 - val_accuracy: 0.2467
# Epoch 3/80
# 75/75 [==============================] - 5s 61ms/step - loss: 2.1325 - accuracy: 0.2204 - val_loss: 2.1801 - val_accuracy: 0.2633
# Epoch 4/80
# 75/75 [==============================] - 5s 61ms/step - loss: 2.0454 - accuracy: 0.2692 - val_loss: 2.1421 - val_accuracy: 0.2833
# Epoch 5/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.9822 - accuracy: 0.2725 - val_loss: 2.0998 - val_accuracy: 0.3667
# Epoch 6/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.9206 - accuracy: 0.3113 - val_loss: 2.0627 - val_accuracy: 0.3317
# Epoch 7/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.8647 - accuracy: 0.3300 - val_loss: 2.0291 - val_accuracy: 0.3333
# Epoch 8/80
# 75/75 [==============================] - 5s 62ms/step - loss: 1.8250 - accuracy: 0.3479 - val_loss: 1.9854 - val_accuracy: 0.4100
# Epoch 9/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.7733 - accuracy: 0.3625 - val_loss: 1.9551 - val_accuracy: 0.3917
# Epoch 10/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.7199 - accuracy: 0.3913 - val_loss: 1.9164 - val_accuracy: 0.3900
# Epoch 11/80
# 75/75 [==============================] - 5s 61ms/step - loss: 1.6820 - accuracy: 0.4200 - val_loss: 1.8806 - val_accuracy: 0.4217
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6715 - accuracy: 0.7379 - val_loss: 1.5340 - val_accuracy: 0.4050
# Epoch 71/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6576 - accuracy: 0.7437 - val_loss: 1.4963 - val_accuracy: 0.4067
# Epoch 72/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6648 - accuracy: 0.7396 - val_loss: 1.5085 - val_accuracy: 0.4133
# Epoch 73/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6534 - accuracy: 0.7487 - val_loss: 1.5300 - val_accuracy: 0.4050
# Epoch 74/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6275 - accuracy: 0.7558 - val_loss: 1.5343 - val_accuracy: 0.4083
# Epoch 75/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6236 - accuracy: 0.7592 - val_loss: 1.5497 - val_accuracy: 0.3967
# Epoch 76/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6096 - accuracy: 0.7617 - val_loss: 1.5398 - val_accuracy: 0.4017
# Epoch 77/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6283 - accuracy: 0.7538 - val_loss: 1.5813 - val_accuracy: 0.3850
# Epoch 78/80
# 75/75 [==============================] - 5s 62ms/step - loss: 0.6043 - accuracy: 0.7613 - val_loss: 1.5498 - val_accuracy: 0.4017
# Epoch 79/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6133 - accuracy: 0.7608 - val_loss: 1.5228 - val_accuracy: 0.4017
# Epoch 80/80
# 75/75 [==============================] - 5s 61ms/step - loss: 0.6055 - accuracy: 0.7579 - val_loss: 1.5347 - val_accuracy: 0.4100
# CNN #2 Time: 6.44 minute

# %% [markdown]
# ##  ***Generating evaluation metrics CNN2 ***
#
#  Asignamos los resultados de model.fit a un objeto history. Esto nos permitirá ver los resultados de las pruebas

# %%
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn2.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
# Out:
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 101ms/step

# %%
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN2 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn2_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# --------------------------------------------
# -----------------CNN2 Summary---------------
# --------------------------------------------
# CNN Time: 6.44 minute
# F1 score: 0.4270821688675332
# Accuracy score: 0.41
# Precision score: 0.41
# Recall score: 0.41

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history_cnn2.history['accuracy'])
plt.plot(history_cnn2.history['val_accuracy'])
plt.title('CNN2 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
hist_cnn2 = history_cnn2.history
loss = hist_cnn2['loss']
val_loss = hist_cnn2['val_loss']
x = np.arange(80) + 1  #nro de epchs +1

plt.title("CNN2: Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
# Otra forma de obtener label de train y test pero   no funcina con el from_directry por que  con cada ejecuciion se actualizan los sets
#train_label = np.concatenate([y for x, y in train_esc], axis=0)
#valid_label = np.concatenate([y for x, y in valid_esc], axis=0)

# %%
yPred

# %%
yTest

# %%
# cm is the confusion matrix, names are the names of the classes.
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=90)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# CNN report and analysis
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("---------Plotting confusion matrix---------")
print("-------------------------------------------")

plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN2 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred ))
# Out:
# -------------------------------------------
# ---------Plotting confusion matrix---------
# -------------------------------------------
# ------------------------------------------------------------
# ----------------- Classification Report CNN2 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.13      0.17      0.15        52
#          1.0       0.56      0.62      0.59        52
#          2.0       0.09      0.07      0.08        69
#          3.0       0.59      0.53      0.56        60
#          4.0       0.83      0.71      0.77        69
#          5.0       0.05      0.07      0.06        55
#          6.0       0.68      0.65      0.66        68
#          7.0       0.78      0.59      0.67        59
#          8.0       0.03      0.04      0.03        54
#          9.0       0.62      0.55      0.58        62
#
#     accuracy                           0.41       600
#    macro avg       0.44      0.40      0.42       600
# weighted avg       0.45      0.41      0.43       600

# %% [markdown]
# #Model #3
#
# ---

# %%
from keras.callbacks import ModelCheckpoint
#from keras.preprocessing.sequence import pad_sequences
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, GRU
from keras.layers import Activation, Dropout, Flatten, Dense, TimeDistributed


cnn3 = Sequential()

cnn3.add(Conv2D(32,(3,3),padding='same',
                input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),
                activation='tanh'))
cnn2.add(Dropout(0.6))   
cnn3.add(Conv2D(32,(3,3),strides=2,padding='same',activation='tanh'))
cnn3.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn3.add(Conv2D(64,(3,3),strides=2,padding='same',activation='tanh'))
cnn2.add(Dropout(0.6))

cnn3.add(Conv2D(64,(3,3),strides=2,padding='same',activation='tanh'))
cnn3.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn3.add(Conv2D(128,(3,3),strides=2,padding='same',activation='tanh'))
cnn2.add(Dropout(0.6))
cnn3.add(Conv2D(128,(3,3),strides=2,padding='same',activation='tanh'))
cnn3.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn3.add(Conv2D(256,(3,3),strides=2,padding='same',activation='tanh'))
cnn2.add(Dropout(0.6))
cnn3.add(Conv2D(256,(3,3),strides=2,padding='same',activation='tanh'))
#cnn3.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))


cnn3.add(Flatten())
cnn3.add(Dense(32))
cnn2.add(Dropout(0.5))
cnn3.add(Dense(32))
cnn2.add(Dropout(0.5))
cnn3.add(Dense(32))
cnn2.add(Dropout(0.5))
cnn3.add(Dense(32))
cnn2.add(Dropout(0.5))
cnn3.add(Dense(10))
cnn3.add(Activation('softmax'))

cnn3.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_212 (Conv2D)         (None, 256, 256, 32)      896
#
#  conv2d_213 (Conv2D)         (None, 128, 128, 32)      9248
#
#  max_pooling2d_94 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_214 (Conv2D)         (None, 32, 32, 64)        18496
#
#  conv2d_215 (Conv2D)         (None, 16, 16, 64)        36928
#
#  max_pooling2d_95 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_216 (Conv2D)         (None, 4, 4, 128)         73856
#
#  conv2d_217 (Conv2D)         (None, 2, 2, 128)         147584
#
#  max_pooling2d_96 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  conv2d_218 (Conv2D)         (None, 1, 1, 256)         295168
#
#  conv2d_219 (Conv2D)         (None, 1, 1, 256)         590080
#
#  flatten_27 (Flatten)        (None, 256)               0
#
#  dense_105 (Dense)           (None, 32)                8224
#
#  dense_106 (Dense)           (None, 32)                1056
#
#  dense_107 (Dense)           (None, 32)                1056
#
#  dense_108 (Dense)           (None, 32)                1056
#
#  dense_109 (Dense)           (None, 10)                330
#
#  activation_51 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,183,978
# Trainable params: 1,183,978
# Non-trainable params: 0
# _________________________________________________________________

# %%
#cnn3.compile(
#      loss=keras.losses.sparse_categorical_crossentropy, 
#      optimizer=tf.optimizers.Adam()
#      ,metrics=['accuracy']
#)
cnn3.compile(
      loss=keras.losses.sparse_categorical_crossentropy, 
      optimizer=tf.keras.optimizers.legacy.Adagrad(learning_rate=INIT_LR, decay=INIT_LR / 100)
      ,metrics=['accuracy']
)

# %%
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn3 = cnn3.fit(train_esc, epochs=250, validation_data=valid_esc)
end1 = time.time()
cnn3_time = end1-start1
print("CNN #3 Time: {:0.2f} minute".format(cnn3_time/60.0))
# Out:
# Epoch 1/250
# 75/75 [==============================] - 4s 39ms/step - loss: 2.3025 - accuracy: 0.0938 - val_loss: 2.3026 - val_accuracy: 0.1100
# Epoch 2/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3022 - accuracy: 0.1054 - val_loss: 2.3028 - val_accuracy: 0.1017
# Epoch 3/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3020 - accuracy: 0.1071 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 4/250
# 75/75 [==============================] - 3s 37ms/step - loss: 2.3018 - accuracy: 0.1133 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 5/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3016 - accuracy: 0.1129 - val_loss: 2.3031 - val_accuracy: 0.1017
# Epoch 6/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3014 - accuracy: 0.1163 - val_loss: 2.3032 - val_accuracy: 0.1033
# Epoch 7/250
# 75/75 [==============================] - 3s 35ms/step - loss: 2.3013 - accuracy: 0.1208 - val_loss: 2.3032 - val_accuracy: 0.1050
# Epoch 8/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3011 - accuracy: 0.1254 - val_loss: 2.3031 - val_accuracy: 0.1117
# Epoch 9/250
# 75/75 [==============================] - 3s 37ms/step - loss: 2.3009 - accuracy: 0.1225 - val_loss: 2.3031 - val_accuracy: 0.1167
# Epoch 10/250
# 75/75 [==============================] - 3s 35ms/step - loss: 2.3008 - accuracy: 0.1346 - val_loss: 2.3031 - val_accuracy: 0.1183
# Epoch 11/250
# 75/75 [==============================] - 3s 35ms/step - loss: 2.3006 - accuracy: 0.1275 - val_loss: 2.3030 - val_accuracy: 0.1250
# Epoch 12/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3004 - accuracy: 0.1308 - val_loss: 2.3030 - val_accuracy: 0.1350
# Epoch 13/250
# 75/75 [==============================] - 3s 37ms/step - loss: 2.3002 - accuracy: 0.1354 - val_loss: 2.3029 - val_accuracy: 0.1333
# Epoch 14/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.3001 - accuracy: 0.1446 - val_loss: 2.3028 - val_accuracy: 0.1317
# Epoch 15/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.2998 - accuracy: 0.1525 - val_loss: 2.3027 - val_accuracy: 0.1417
# Epoch 16/250
# 75/75 [==============================] - 3s 35ms/step - loss: 2.2997 - accuracy: 0.1513 - val_loss: 2.3026 - val_accuracy: 0.1417
# Epoch 17/250
# 75/75 [==============================] - 3s 36ms/step - loss: 2.2995 - accuracy: 0.1471 - val_loss: 2.3024 - val_accuracy: 0.1467
#  Asignamos los resultados de model.fit a un objeto history. Esto nos permitirá ver los resultados de las pruebas

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn3.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN3 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn3_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 156ms/step
# --------------------------------------------
# -----------------CNN3 Summary---------------
# --------------------------------------------
# CNN Time: 12.50 minute
# F1 score: 0.5871271802933857
# Accuracy score: 0.5866666666666667
# Precision score: 0.5866666666666667
# Recall score: 0.5866666666666667

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn3.history['accuracy'])
plt.plot(history_cnn3.history['val_accuracy'])
plt.title('CNN3 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn3 = history_cnn3.history
loss = hist_cnn3['loss']
val_loss = hist_cnn3['val_loss']
x = np.arange(250) + 1

plt.title("CNN3: Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
#cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
#cnn_accuracy = metrics.accuracy_score(yTest, yPred)
#cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("--------Plotting confusion matrix'---------")
print("-------------------------------------------")


plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN3 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred , target_names=labelNames))
# Out:
# -------------------------------------------
# --------Plotting confusion matrix'---------
# -------------------------------------------
# ------------------------------------------------------------
# ----------------- Classification Report CNN3 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        bird1       0.61      0.69      0.65        52
#       bird10       0.63      0.65      0.64        52
#        bird2       0.51      0.45      0.48        69
#        bird3       0.71      0.62      0.66        60
#        bird4       0.72      0.59      0.65        69
#        bird5       0.67      0.60      0.63        55
#        bird6       0.51      0.59      0.54        68
#        bird7       0.57      0.54      0.56        59
#        bird8       0.50      0.69      0.58        54
#        bird9       0.53      0.50      0.51        62
#
#     accuracy                           0.59       600
#    macro avg       0.60      0.59      0.59       600
# weighted avg       0.59      0.59      0.59       600

# %% [markdown]
# # Model#4
#
# ---

# %%
# Create CNN #4 model
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

cnn4 = Sequential()
    
cnn4.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn4.add(BatchNormalization())
cnn4.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn4.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
cnn4.add(BatchNormalization())

cnn4.add(Flatten())
cnn4.add(Dense(32,activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))
cnn4.add(Dense(32,activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))
cnn4.add(Dense(32,activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))
cnn4.add(Dense(32,activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))
cnn4.add(Dense(10))
cnn4.add(Activation('softmax'))

cnn4.summary()

# %%
# Compile model
cnn4.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(),
    metrics=['accuracy'],
)

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn4 = cnn4.fit(train_esc, epochs=100, validation_data=valid_esc)
end1 = time.time()
cnn4_time = end1-start1
print("CNN #4 Time: {:0.2f} minute".format(cnn4_time/60.0))

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn4 = cnn4.fit(train_esc, epochs=100, validation_data=valid_esc)
end1 = time.time()
cnn4_time = end1-start1
print("CNN #4 Time: {:0.2f} minute".format(cnn4_time/60.0))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 13s 49ms/step - loss: 3.1321 - accuracy: 0.1083 - val_loss: 2.3233 - val_accuracy: 0.1133
# Epoch 2/100
# 75/75 [==============================] - 4s 44ms/step - loss: 2.8460 - accuracy: 0.1271 - val_loss: 2.3174 - val_accuracy: 0.0900
# Epoch 3/100
# 75/75 [==============================] - 3s 42ms/step - loss: 2.5357 - accuracy: 0.1517 - val_loss: 2.3000 - val_accuracy: 0.0967
# Epoch 4/100
# 75/75 [==============================] - 3s 42ms/step - loss: 2.3745 - accuracy: 0.1667 - val_loss: 2.5026 - val_accuracy: 0.1217
# Epoch 5/100
# 75/75 [==============================] - 4s 43ms/step - loss: 2.1545 - accuracy: 0.2054 - val_loss: 1.8184 - val_accuracy: 0.2867
# Epoch 6/100
# 75/75 [==============================] - 4s 44ms/step - loss: 2.0007 - accuracy: 0.2317 - val_loss: 2.0845 - val_accuracy: 0.1800
# Epoch 7/100
# 75/75 [==============================] - 3s 42ms/step - loss: 1.8298 - accuracy: 0.2962 - val_loss: 1.9347 - val_accuracy: 0.2500
# Epoch 8/100
# 75/75 [==============================] - 3s 42ms/step - loss: 1.7324 - accuracy: 0.3158 - val_loss: 1.2895 - val_accuracy: 0.5333
# Epoch 9/100
# 75/75 [==============================] - 4s 44ms/step - loss: 1.5643 - accuracy: 0.3942 - val_loss: 1.0458 - val_accuracy: 0.6883
# Epoch 10/100
# 75/75 [==============================] - 3s 42ms/step - loss: 1.4827 - accuracy: 0.4104 - val_loss: 1.0237 - val_accuracy: 0.6200
# Epoch 11/100
# 75/75 [==============================] - 3s 42ms/step - loss: 1.3784 - accuracy: 0.4462 - val_loss: 0.9661 - val_accuracy: 0.6633
# Epoch 12/100
# 75/75 [==============================] - 4s 43ms/step - loss: 1.3205 - accuracy: 0.4725 - val_loss: 0.7480 - val_accuracy: 0.8467
# Epoch 13/100
# 75/75 [==============================] - 4s 46ms/step - loss: 1.2479 - accuracy: 0.5129 - val_loss: 0.8436 - val_accuracy: 0.7967
# Epoch 14/100
# 75/75 [==============================] - 3s 42ms/step - loss: 0.2500 - accuracy: 0.9258 - val_loss: 0.0450 - val_accuracy: 0.9917
# Epoch 93/100
# 75/75 [==============================] - 3s 42ms/step - loss: 0.2402 - accuracy: 0.9271 - val_loss: 0.0180 - val_accuracy: 0.9950
# Epoch 94/100
# 75/75 [==============================] - 4s 45ms/step - loss: 0.2718 - accuracy: 0.9229 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 95/100
# 75/75 [==============================] - 4s 44ms/step - loss: 0.2275 - accuracy: 0.9292 - val_loss: 0.0123 - val_accuracy: 0.9967
# Epoch 96/100
# 75/75 [==============================] - 4s 43ms/step - loss: 0.2355 - accuracy: 0.9254 - val_loss: 0.0856 - val_accuracy: 0.9783
# Epoch 97/100
# 75/75 [==============================] - 4s 44ms/step - loss: 0.2420 - accuracy: 0.9225 - val_loss: 0.0313 - val_accuracy: 0.9950
# Epoch 98/100
# 75/75 [==============================] - 4s 46ms/step - loss: 0.2349 - accuracy: 0.9212 - val_loss: 0.0364 - val_accuracy: 0.9933
# Epoch 99/100
# 75/75 [==============================] - 4s 43ms/step - loss: 0.2123 - accuracy: 0.9275 - val_loss: 0.0969 - val_accuracy: 0.9833
# Epoch 100/100
# 75/75 [==============================] - 3s 43ms/step - loss: 0.2619 - accuracy: 0.9246 - val_loss: 0.0014 - val_accuracy: 1.0000
# CNN #4 Time: 6.10 minute

# %% [markdown]
# ##  ***Generating evaluation metrics CNN4 ***

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn4.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN4 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn4_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 345ms/step
# --------------------------------------------
# -----------------CNN4 Summary---------------
# --------------------------------------------
# CNN Time: 6.10 minute
# F1 score: 1.0
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn4.history['accuracy'])
plt.plot(history_cnn4.history['val_accuracy'])
plt.title('CNN4 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn4 = history_cnn4.history
loss = hist_cnn4['loss']
val_loss = hist_cnn4['val_loss']
x = np.arange(100) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn4.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
  
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN4 Summary---------------")
print("-------------------------------------------")
print("CNN2 Trainning Time: {:0.2f} minute".format(cnn4_time/60.0))
print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN4 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred))
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# -------------------------------------------
# -----------------CNN4 Summary---------------
# -------------------------------------------
# CNN2 Trainning Time: 8.42 minute
# Plotting confusion matrix
# ------------------------------------------------------------
# ----------------- Classification Report CNN4 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.29      1.00      0.45        52
#          1.0       0.85      0.90      0.88        52
#          2.0       0.00      0.00      0.00        69
#          3.0       0.86      0.80      0.83        60
#          4.0       0.98      0.94      0.96        69
#          5.0       0.48      0.98      0.64        55
#          6.0       0.80      0.94      0.86        68
#          7.0       0.33      0.03      0.06        59
#          8.0       0.00      0.00      0.00        54
#          9.0       0.94      0.71      0.81        62
#
#     accuracy                           0.63       600
#    macro avg       0.55      0.63      0.55       600
# weighted avg       0.56      0.63      0.56       600
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #Model#5  :  CNN4-DENSENET
# Tranfer Learning - DenseNet
#
#
# ---

# %%
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D,BatchNormalization
#from keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.optimizers import Adam , SGD, RMSprop

# %%
base_denseNet = tf.keras.applications.densenet.DenseNet201(weights='imagenet', input_shape =(IMAGE_HEIGHT, IMAGE_WIDTH, NO_CHANNELS),
                                                     include_top=False)

for layer in base_denseNet.layers:
    layer.trainable = False

# %%
model_DenseNet=Sequential()
model_DenseNet.add(base_denseNet)
model_DenseNet.add(GlobalAveragePooling2D())
model_DenseNet.add(Flatten())
model_DenseNet.add(Dense(300, activation="relu"))
model_DenseNet.add(BatchNormalization())
#model_DenseNet.add(Dropout(0.5))

model_DenseNet.add(Dense(300, activation="relu"))
model_DenseNet.add(BatchNormalization())
model_DenseNet.add(Dropout(0.5))

model_DenseNet.add(Dense(300, activation="relu"))
model_DenseNet.add(BatchNormalization())
#model_DenseNet.add(Dropout(0.5))

model_DenseNet.add(Dense(100,activation='relu'))
model_DenseNet.add(BatchNormalization())
model_DenseNet.add(Dropout(0.5))

model_DenseNet.add(Dense(NO_CLASSES,activation="softmax"))
model_DenseNet.summary()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 8, 8, 1920)        18321984
#
#  global_average_pooling2d_8   (None, 1920)             0
#  (GlobalAveragePooling2D)
#
#  flatten_36 (Flatten)        (None, 1920)              0
#
#  dense_136 (Dense)           (None, 300)               576300
#
#  batch_normalization_19 (Bat  (None, 300)              1200
#  chNormalization)
#
#  dense_137 (Dense)           (None, 300)               90300
#
#  batch_normalization_20 (Bat  (None, 300)              1200
#  chNormalization)
#
#  dropout_92 (Dropout)        (None, 300)               0
#
#  dense_138 (Dense)           (None, 300)               90300
#
#  batch_normalization_21 (Bat  (None, 300)              1200
#  chNormalization)
#
#  dense_139 (Dense)           (None, 100)               30100
#
#  batch_normalization_22 (Bat  (None, 100)              400
#  chNormalization)
#
#  dropout_93 (Dropout)        (None, 100)               0
#
#  dense_140 (Dense)           (None, 10)                1010
#
# =================================================================
# Total params: 19,113,994
# Trainable params: 790,010
# Non-trainable params: 18,323,984
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
#initial_learning_rate = 1e-2,final_learning_rate = 1e-6,decay_steps = 10000
learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
model_DenseNet.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=1e-5, patience=10, mode='auto',
                                              restore_best_weights=False, verbose=1),
                ModelCheckpoint(filepath='mask_detection_model.h5', monitor='accuracy', save_best_only=True, 
                                save_weights_only=False,
                                mode='auto', save_freq='epoch', verbose=1)]

# %%
start1 = time.time()
# Train model for 10 epochs, capture the history
history_denseNet = model_DenseNet.fit(train_esc, validation_data = valid_esc, epochs = 250, steps_per_epoch=len(train_esc),
                    callbacks = [callbacks], verbose = 1)
end1 = time.time()
denseNet_time = end1-start1
print("DenseNet Time: {:0.2f} minute".format(denseNet_time/60.0))
# Out:
# Epoch 1/250
# 74/75 [============================>.] - ETA: 0s - loss: 3.6084 - accuracy: 0.1018
# Epoch 1: accuracy improved from -inf to 0.10208, saving model to mask_detection_model.h5
# 75/75 [==============================] - 25s 130ms/step - loss: 3.6098 - accuracy: 0.1021 - val_loss: 2.3531 - val_accuracy: 0.1117
# Epoch 2/250
# 75/75 [==============================] - ETA: 0s - loss: 3.5100 - accuracy: 0.1142
# Epoch 2: accuracy improved from 0.10208 to 0.11417, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 3.5100 - accuracy: 0.1142 - val_loss: 2.3969 - val_accuracy: 0.1133
# Epoch 3/250
# 75/75 [==============================] - ETA: 0s - loss: 3.3966 - accuracy: 0.1163
# Epoch 3: accuracy improved from 0.11417 to 0.11625, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 3.3966 - accuracy: 0.1163 - val_loss: 2.4157 - val_accuracy: 0.1317
# Epoch 4/250
# 74/75 [============================>.] - ETA: 0s - loss: 3.3256 - accuracy: 0.1102
# Epoch 4: accuracy did not improve from 0.11625
# 75/75 [==============================] - 5s 70ms/step - loss: 3.3192 - accuracy: 0.1104 - val_loss: 2.4117 - val_accuracy: 0.1567
# Epoch 5/250
# 74/75 [============================>.] - ETA: 0s - loss: 3.2883 - accuracy: 0.1271
# Epoch 5: accuracy improved from 0.11625 to 0.12750, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 3.2835 - accuracy: 0.1275 - val_loss: 2.3880 - val_accuracy: 0.1633
# Epoch 6/250
# 75/75 [==============================] - ETA: 0s - loss: 3.1747 - accuracy: 0.1625
# Epoch 6: accuracy improved from 0.12750 to 0.16250, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 3.1747 - accuracy: 0.1625 - val_loss: 2.3540 - val_accuracy: 0.1833
# Epoch 7/250
# 74/75 [============================>.] - ETA: 0s - loss: 3.1673 - accuracy: 0.1512
# Epoch 7: accuracy did not improve from 0.16250
# 75/75 [==============================] - 5s 70ms/step - loss: 3.1639 - accuracy: 0.1513 - val_loss: 2.3258 - val_accuracy: 0.1833
# Epoch 8/250
# 75/75 [==============================] - ETA: 0s - loss: 3.0420 - accuracy: 0.1637
# Epoch 8: accuracy improved from 0.16250 to 0.16375, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 3.0420 - accuracy: 0.1637 - val_loss: 2.2941 - val_accuracy: 0.1983
# Epoch 9/250
# 74/75 [============================>.] - ETA: 0s - loss: 3.0255 - accuracy: 0.1647
# Epoch 9: accuracy improved from 0.16375 to 0.16417, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 3.0311 - accuracy: 0.1642 - val_loss: 2.2544 - val_accuracy: 0.2017
# Epoch 10/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.9578 - accuracy: 0.1753
# Epoch 10: accuracy improved from 0.16417 to 0.17500, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 2.9541 - accuracy: 0.1750 - val_loss: 2.2221 - val_accuracy: 0.2233
# Epoch 11/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.8490 - accuracy: 0.1871
# Epoch 11: accuracy improved from 0.17500 to 0.18667, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 90ms/step - loss: 2.8519 - accuracy: 0.1867 - val_loss: 2.1915 - val_accuracy: 0.2350
# Epoch 12/250
# 75/75 [==============================] - ETA: 0s - loss: 2.8572 - accuracy: 0.1950
# Epoch 12: accuracy improved from 0.18667 to 0.19500, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 85ms/step - loss: 2.8572 - accuracy: 0.1950 - val_loss: 2.1518 - val_accuracy: 0.2350
# Epoch 13/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.8307 - accuracy: 0.1989
# Epoch 13: accuracy improved from 0.19500 to 0.19917, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 2.8304 - accuracy: 0.1992 - val_loss: 2.1249 - val_accuracy: 0.2517
# Epoch 14/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.7535 - accuracy: 0.2145
# Epoch 14: accuracy improved from 0.19917 to 0.21542, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 85ms/step - loss: 2.7499 - accuracy: 0.2154 - val_loss: 2.0889 - val_accuracy: 0.2667
# Epoch 15/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.7228 - accuracy: 0.2061
# Epoch 15: accuracy did not improve from 0.21542
# 75/75 [==============================] - 5s 69ms/step - loss: 2.7231 - accuracy: 0.2054 - val_loss: 2.0503 - val_accuracy: 0.2883
# Epoch 16/250
# 75/75 [==============================] - ETA: 0s - loss: 2.6980 - accuracy: 0.2125
# Epoch 16: accuracy did not improve from 0.21542
# 75/75 [==============================] - 6s 71ms/step - loss: 2.6980 - accuracy: 0.2125 - val_loss: 2.0264 - val_accuracy: 0.3017
# Epoch 17/250
# 75/75 [==============================] - ETA: 0s - loss: 2.6813 - accuracy: 0.2233
# Epoch 17: accuracy improved from 0.21542 to 0.22333, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 2.6813 - accuracy: 0.2233 - val_loss: 1.9943 - val_accuracy: 0.3100
# Epoch 18/250
# 75/75 [==============================] - ETA: 0s - loss: 2.6346 - accuracy: 0.2250
# Epoch 18: accuracy improved from 0.22333 to 0.22500, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 85ms/step - loss: 2.6346 - accuracy: 0.2250 - val_loss: 1.9663 - val_accuracy: 0.3167
# Epoch 19/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.5798 - accuracy: 0.2437
# Epoch 19: accuracy improved from 0.22500 to 0.24292, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 2.5810 - accuracy: 0.2429 - val_loss: 1.9428 - val_accuracy: 0.3183
# Epoch 20/250
# 75/75 [==============================] - ETA: 0s - loss: 2.5083 - accuracy: 0.2650
# Epoch 20: accuracy improved from 0.24292 to 0.26500, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 2.5083 - accuracy: 0.2650 - val_loss: 1.9185 - val_accuracy: 0.3317
# Epoch 21/250
# 75/75 [==============================] - ETA: 0s - loss: 2.5053 - accuracy: 0.2571
# Epoch 21: accuracy did not improve from 0.26500
# 75/75 [==============================] - 5s 69ms/step - loss: 2.5053 - accuracy: 0.2571 - val_loss: 1.9071 - val_accuracy: 0.3500
# Epoch 22/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.4971 - accuracy: 0.2703
# Epoch 22: accuracy improved from 0.26500 to 0.27125, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 2.4895 - accuracy: 0.2713 - val_loss: 1.8775 - val_accuracy: 0.3667
# Epoch 23/250
# 75/75 [==============================] - ETA: 0s - loss: 2.4952 - accuracy: 0.2533
# Epoch 23: accuracy did not improve from 0.27125
# 75/75 [==============================] - 5s 70ms/step - loss: 2.4952 - accuracy: 0.2533 - val_loss: 1.8585 - val_accuracy: 0.3783
# Epoch 24/250
# 75/75 [==============================] - ETA: 0s - loss: 2.4431 - accuracy: 0.2692
# Epoch 24: accuracy did not improve from 0.27125
# 75/75 [==============================] - 5s 70ms/step - loss: 2.4431 - accuracy: 0.2692 - val_loss: 1.8411 - val_accuracy: 0.3783
# Epoch 25/250
# 75/75 [==============================] - ETA: 0s - loss: 2.3820 - accuracy: 0.2738
# Epoch 25: accuracy improved from 0.27125 to 0.27375, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 2.3820 - accuracy: 0.2738 - val_loss: 1.8254 - val_accuracy: 0.3867
# Epoch 26/250
# 75/75 [==============================] - ETA: 0s - loss: 2.3878 - accuracy: 0.2862
# Epoch 26: accuracy improved from 0.27375 to 0.28625, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 2.3878 - accuracy: 0.2862 - val_loss: 1.8082 - val_accuracy: 0.4000
# Epoch 27/250
# 75/75 [==============================] - ETA: 0s - loss: 2.3099 - accuracy: 0.3058
# Epoch 27: accuracy improved from 0.28625 to 0.30583, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 2.3099 - accuracy: 0.3058 - val_loss: 1.7954 - val_accuracy: 0.3983
# Epoch 28/250
# 75/75 [==============================] - ETA: 0s - loss: 2.3534 - accuracy: 0.2971
# Epoch 28: accuracy did not improve from 0.30583
# 75/75 [==============================] - 5s 70ms/step - loss: 2.3534 - accuracy: 0.2971 - val_loss: 1.7786 - val_accuracy: 0.4100
# Epoch 29/250
# 75/75 [==============================] - ETA: 0s - loss: 2.2824 - accuracy: 0.2988
# Epoch 29: accuracy did not improve from 0.30583
# 75/75 [==============================] - 5s 70ms/step - loss: 2.2824 - accuracy: 0.2988 - val_loss: 1.7713 - val_accuracy: 0.4067
# Epoch 30/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.2559 - accuracy: 0.3100
# Epoch 30: accuracy improved from 0.30583 to 0.31125, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 2.2539 - accuracy: 0.3113 - val_loss: 1.7579 - val_accuracy: 0.4233
# Epoch 31/250
# 75/75 [==============================] - 7s 84ms/step - loss: 2.0527 - accuracy: 0.3608 - val_loss: 1.6568 - val_accuracy: 0.4500
# Epoch 42/250
# 75/75 [==============================] - ETA: 0s - loss: 2.0962 - accuracy: 0.3508
# Epoch 42: accuracy did not improve from 0.36083
# 75/75 [==============================] - 6s 71ms/step - loss: 2.0962 - accuracy: 0.3508 - val_loss: 1.6459 - val_accuracy: 0.4533
# Epoch 43/250
# 75/75 [==============================] - ETA: 0s - loss: 2.0143 - accuracy: 0.3704
# Epoch 43: accuracy improved from 0.36083 to 0.37042, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 85ms/step - loss: 2.0143 - accuracy: 0.3704 - val_loss: 1.6439 - val_accuracy: 0.4550
# Epoch 44/250
# 75/75 [==============================] - ETA: 0s - loss: 2.0393 - accuracy: 0.3729
# Epoch 44: accuracy improved from 0.37042 to 0.37292, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 2.0393 - accuracy: 0.3729 - val_loss: 1.6387 - val_accuracy: 0.4567
# Epoch 45/250
# 75/75 [==============================] - ETA: 0s - loss: 2.0379 - accuracy: 0.3613
# Epoch 45: accuracy did not improve from 0.37292
# 75/75 [==============================] - 5s 70ms/step - loss: 2.0379 - accuracy: 0.3613 - val_loss: 1.6332 - val_accuracy: 0.4633
# Epoch 46/250
# 74/75 [============================>.] - ETA: 0s - loss: 2.0047 - accuracy: 0.3619
# Epoch 46: accuracy did not improve from 0.37292
# 75/75 [==============================] - 6s 71ms/step - loss: 2.0011 - accuracy: 0.3625 - val_loss: 1.6252 - val_accuracy: 0.4667
# Epoch 47/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.9779 - accuracy: 0.3834
# Epoch 47: accuracy improved from 0.37292 to 0.38458, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 1.9737 - accuracy: 0.3846 - val_loss: 1.6198 - val_accuracy: 0.4650
# Epoch 48/250
# 75/75 [==============================] - ETA: 0s - loss: 2.0198 - accuracy: 0.3800
# Epoch 48: accuracy did not improve from 0.38458
# 75/75 [==============================] - 6s 71ms/step - loss: 2.0198 - accuracy: 0.3800 - val_loss: 1.6159 - val_accuracy: 0.4700
# Epoch 49/250
# 75/75 [==============================] - ETA: 0s - loss: 1.9710 - accuracy: 0.3667
# Epoch 49: accuracy did not improve from 0.38458
# 75/75 [==============================] - 5s 69ms/step - loss: 1.9710 - accuracy: 0.3667 - val_loss: 1.6132 - val_accuracy: 0.4700
# Epoch 50/250
# 75/75 [==============================] - ETA: 0s - loss: 1.9602 - accuracy: 0.3929
# Epoch 50: accuracy improved from 0.38458 to 0.39292, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 85ms/step - loss: 1.9602 - accuracy: 0.3929 - val_loss: 1.6106 - val_accuracy: 0.4783
# Epoch 51/250
# 75/75 [==============================] - ETA: 0s - loss: 1.9039 - accuracy: 0.3942
# Epoch 51: accuracy improved from 0.39292 to 0.39417, saving model to mask_detection_model.h5
# Epoch 72: accuracy improved from 0.44167 to 0.44917, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 1.7410 - accuracy: 0.4492 - val_loss: 1.5021 - val_accuracy: 0.5033
# Epoch 73/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6677 - accuracy: 0.4617
# Epoch 73: accuracy improved from 0.44917 to 0.46167, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 1.6677 - accuracy: 0.4617 - val_loss: 1.4976 - val_accuracy: 0.5067
# Epoch 74/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6941 - accuracy: 0.4667
# Epoch 74: accuracy improved from 0.46167 to 0.46667, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 1.6941 - accuracy: 0.4667 - val_loss: 1.4983 - val_accuracy: 0.5100
# Epoch 75/250
# 75/75 [==============================] - ETA: 0s - loss: 1.7332 - accuracy: 0.4471
# Epoch 75: accuracy did not improve from 0.46667
# 75/75 [==============================] - 5s 70ms/step - loss: 1.7332 - accuracy: 0.4471 - val_loss: 1.4929 - val_accuracy: 0.5167
# Epoch 76/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6846 - accuracy: 0.4633
# Epoch 76: accuracy did not improve from 0.46667
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6846 - accuracy: 0.4633 - val_loss: 1.4912 - val_accuracy: 0.5117
# Epoch 77/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6515 - accuracy: 0.4750
# Epoch 77: accuracy improved from 0.46667 to 0.47500, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 90ms/step - loss: 1.6515 - accuracy: 0.4750 - val_loss: 1.4887 - val_accuracy: 0.5117
# Epoch 78/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.6161 - accuracy: 0.4582
# Epoch 78: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 71ms/step - loss: 1.6155 - accuracy: 0.4588 - val_loss: 1.4818 - val_accuracy: 0.5183
# Epoch 79/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6595 - accuracy: 0.4638
# Epoch 79: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6595 - accuracy: 0.4638 - val_loss: 1.4808 - val_accuracy: 0.5217
# Epoch 80/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6949 - accuracy: 0.4600
# Epoch 80: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6949 - accuracy: 0.4600 - val_loss: 1.4774 - val_accuracy: 0.5233
# Epoch 81/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.6418 - accuracy: 0.4540
# Epoch 81: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6358 - accuracy: 0.4563 - val_loss: 1.4767 - val_accuracy: 0.5217
# Epoch 82/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6870 - accuracy: 0.4563
# Epoch 82: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6870 - accuracy: 0.4563 - val_loss: 1.4715 - val_accuracy: 0.5250
# Epoch 83/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6233 - accuracy: 0.4742
# Epoch 83: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6233 - accuracy: 0.4742 - val_loss: 1.4691 - val_accuracy: 0.5283
# Epoch 84/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6188 - accuracy: 0.4625
# Epoch 84: accuracy did not improve from 0.47500
# 75/75 [==============================] - 5s 69ms/step - loss: 1.6188 - accuracy: 0.4625 - val_loss: 1.4669 - val_accuracy: 0.5267
# Epoch 85/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6465 - accuracy: 0.4629
# Epoch 85: accuracy did not improve from 0.47500
# 75/75 [==============================] - 6s 71ms/step - loss: 1.6465 - accuracy: 0.4629 - val_loss: 1.4621 - val_accuracy: 0.5333
# Epoch 86/250
# 75/75 [==============================] - ETA: 0s - loss: 1.6046 - accuracy: 0.4762
# Epoch 86: accuracy improved from 0.47500 to 0.47625, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 1.6046 - accuracy: 0.4762 - val_loss: 1.4607 - val_accuracy: 0.5283
# Epoch 87/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.6168 - accuracy: 0.4802
# Epoch 87: accuracy improved from 0.47625 to 0.48125, saving model to mask_detection_model.h5
# 75/75 [==============================] - 7s 84ms/step - loss: 1.6155 - accuracy: 0.4812 - val_loss: 1.4570 - val_accuracy: 0.5283
# Epoch 88/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.5791 - accuracy: 0.4894
# Epoch 88: accuracy improved from 0.48125 to 0.48875, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 83ms/step - loss: 1.5854 - accuracy: 0.4888 - val_loss: 1.4543 - val_accuracy: 0.5333
# Epoch 89/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.6091 - accuracy: 0.4776
# Epoch 89: accuracy did not improve from 0.48875
# 75/75 [==============================] - 5s 70ms/step - loss: 1.6116 - accuracy: 0.4762 - val_loss: 1.4536 - val_accuracy: 0.5300
# Epoch 90/250
# 74/75 [============================>.] - ETA: 0s - loss: 1.5946 - accuracy: 0.4941
# Epoch 90: accuracy improved from 0.48875 to 0.49208, saving model to mask_detection_model.h5
# 75/75 [==============================] - 6s 84ms/step - loss: 1.5982 - accuracy: 0.4921 - val_loss: 1.4528 - val_accuracy: 0.5367
# Epoch 91/250
# 75/75 [==============================] - ETA: 0s - loss: 1.5640 - accuracy: 0.4854
# Epoch 91: accuracy did not improve from 0.49208
# 75/75 [==============================] - 5s 70ms/step - loss: 1.5640 - accuracy: 0.4854 - val_loss: 1.4463 - val_accuracy: 0.5333
# Epoch 92/250
# 75/75 [==============================] - ETA: 0s - loss: 1.5998 - accuracy: 0.4829
# Epoch 92: accuracy did not improve from 0.49208
# Epoch 103/250
# 75/75 [==============================] - ETA: 0s - loss: 1.5151 - accuracy: 0.4942
# Epoch 103: accuracy did not improve from 0.51000
# 75/75 [==============================] - 5s 69ms/step - loss: 1.5151 - accuracy: 0.4942 - val_loss: 1.4213 - val_accuracy: 0.5433
# Epoch 104/250
# 75/75 [==============================] - ETA: 0s - loss: 1.5474 - accuracy: 0.5021
# Epoch 104: accuracy did not improve from 0.51000
# 75/75 [==============================] - 5s 70ms/step - loss: 1.5474 - accuracy: 0.5021 - val_loss: 1.4204 - val_accuracy: 0.5433
# Epoch 104: early stopping
# DenseNet Time: 10.62 minute

# %%
##---------------------------------------------
##------------ Clasification Repor ------------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(model_DenseNet.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN5 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(denseNet_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 3s 3s/step
# --------------------------------------------
# -----------------CNN5 Summary---------------
# --------------------------------------------
# CNN Time: 10.62 minute
# F1 score: 0.5420588013528738
# Accuracy score: 0.5433333333333333
# Precision score: 0.5433333333333333
# Recall score: 0.5433333333333333

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_denseNet.history['accuracy'])
plt.plot(history_denseNet.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_denseNet = history_denseNet.history
loss = hist_denseNet['loss']
val_loss = hist_denseNet['val_loss']
x = np.arange(104) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------DensNet Summary---------------")
print("-------------------------------------------")
print("CNN Trainning Time: {:0.2f} minute".format(denseNet_time/60.0))
print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred))
# Out:
# -------------------------------------------
# -----------------DensNet Summary---------------
# -------------------------------------------
# CNN2 Trainning Time: 10.62 minute
# Plotting confusion matrix
# ------------------------------------------------------------
# ----------------- Classification Report CNN2 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.63      0.52        52
#          1.0       0.54      0.65      0.59        52
#          2.0       0.54      0.36      0.43        69
#          3.0       0.67      0.60      0.63        60
#          4.0       0.40      0.46      0.43        69
#          5.0       0.77      0.67      0.72        55
#          6.0       0.55      0.53      0.54        68
#          7.0       0.45      0.32      0.38        59
#          8.0       0.49      0.72      0.58        54
#          9.0       0.76      0.56      0.65        62
#
#     accuracy                           0.54       600
#    macro avg       0.56      0.55      0.55       600
# weighted avg       0.56      0.54      0.54       600

# %% [markdown]
# ---
#
#
# ## MODEL #6
#
# ---

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

cnn6 = Sequential()
    
cnn6.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn6.add(BatchNormalization())
cnn6.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn6.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
cnn6.add(BatchNormalization())

cnn6.add(Flatten())
cnn6.add(Dense(32,activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(Dropout(0.5))
cnn6.add(Dense(32,activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(Dropout(0.5))
cnn6.add(Dense(32,activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(Dropout(0.5))
cnn6.add(Dense(32,activation='relu'))
cnn6.add(BatchNormalization())
cnn6.add(Dropout(0.5))
cnn6.add(Dense(10))
cnn6.add(Activation('softmax'))

cnn6.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 256, 256, 16)      448
#
#  batch_normalization_32 (Bat  (None, 256, 256, 16)     64
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  batch_normalization_33 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 32)      4640
#
#  batch_normalization_34 (Bat  (None, 128, 128, 32)     128
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  batch_normalization_35 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 32)        9248
#
#  batch_normalization_36 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  batch_normalization_37 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 64)        18496
#
#  batch_normalization_38 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  batch_normalization_39 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_40 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  batch_normalization_41 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_42 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  batch_normalization_43 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 128)         147584
#
#  batch_normalization_44 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  batch_normalization_45 (Bat  (None, 2, 2, 128)        512
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_20 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  batch_normalization_46 (Bat  (None, 1, 1, 128)        512
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 32)                4128
#
#  batch_normalization_47 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 32)                1056
#
#  batch_normalization_48 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  batch_normalization_49 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_13 (Dense)            (None, 32)                1056
#
#  batch_normalization_50 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 10)                330
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,146
# Trainable params: 448,778
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
cnn6.compile(
      loss='sparse_categorical_crossentropy', 
      optimizer=tf.optimizers.Adam()
      ,metrics=['accuracy']
)

# %%
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn6 = cnn6.fit(train_esc, epochs=100, validation_data=valid_esc)
end1 = time.time()
cnn6_time = end1-start1
print("CNN #3 Time: {:0.2f} minute".format(cnn3_time/60.0))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 15s 46ms/step - loss: 3.1036 - accuracy: 0.1171 - val_loss: 2.3238 - val_accuracy: 0.0917
# Epoch 2/100
# 75/75 [==============================] - 3s 40ms/step - loss: 2.9437 - accuracy: 0.1042 - val_loss: 2.3288 - val_accuracy: 0.1150
# Epoch 3/100
# 75/75 [==============================] - 3s 40ms/step - loss: 2.7975 - accuracy: 0.1017 - val_loss: 2.3444 - val_accuracy: 0.0867
# Epoch 4/100
# 75/75 [==============================] - 3s 41ms/step - loss: 2.6412 - accuracy: 0.1125 - val_loss: 2.3815 - val_accuracy: 0.0850
# Epoch 5/100
# 75/75 [==============================] - 3s 40ms/step - loss: 2.5822 - accuracy: 0.1125 - val_loss: 2.3777 - val_accuracy: 0.1217
# Epoch 6/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.7244 - accuracy: 0.6629 - val_loss: 1.0914 - val_accuracy: 0.6683
# Epoch 85/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6886 - accuracy: 0.6800 - val_loss: 1.0480 - val_accuracy: 0.6783
# Epoch 86/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6987 - accuracy: 0.6671 - val_loss: 0.9972 - val_accuracy: 0.6750
# Epoch 87/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6957 - accuracy: 0.6804 - val_loss: 0.9829 - val_accuracy: 0.6883
# Epoch 88/100
# 75/75 [==============================] - 3s 41ms/step - loss: 0.6528 - accuracy: 0.6687 - val_loss: 0.9787 - val_accuracy: 0.6900
# Epoch 89/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6374 - accuracy: 0.6929 - val_loss: 0.9110 - val_accuracy: 0.6950
# Epoch 90/100
# 75/75 [==============================] - 3s 41ms/step - loss: 0.6509 - accuracy: 0.6938 - val_loss: 1.1801 - val_accuracy: 0.6467
# Epoch 91/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6906 - accuracy: 0.6967 - val_loss: 1.0863 - val_accuracy: 0.6700
# Epoch 92/100
# 75/75 [==============================] - 3s 41ms/step - loss: 0.6521 - accuracy: 0.6829 - val_loss: 1.0787 - val_accuracy: 0.6783
# Epoch 93/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6472 - accuracy: 0.7021 - val_loss: 1.0602 - val_accuracy: 0.6750
# Epoch 94/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6529 - accuracy: 0.6963 - val_loss: 1.1647 - val_accuracy: 0.6750
# Epoch 95/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6498 - accuracy: 0.7113 - val_loss: 1.0215 - val_accuracy: 0.6833
# Epoch 96/100
# 75/75 [==============================] - 3s 41ms/step - loss: 0.6550 - accuracy: 0.7113 - val_loss: 1.0771 - val_accuracy: 0.6883
# Epoch 97/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6121 - accuracy: 0.7142 - val_loss: 1.2356 - val_accuracy: 0.6683
# Epoch 98/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.6022 - accuracy: 0.7233 - val_loss: 0.9890 - val_accuracy: 0.6917
# Epoch 99/100
# 75/75 [==============================] - 3s 40ms/step - loss: 0.5958 - accuracy: 0.7196 - val_loss: 0.9469 - val_accuracy: 0.7050
# Epoch 100/100
# 75/75 [==============================] - 3s 41ms/step - loss: 0.5773 - accuracy: 0.7262 - val_loss: 0.9856 - val_accuracy: 0.6933
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1e88ec0724a9> in <cell line: 6>()
#       4 end1 = time.time()
#       5 cnn6_time = end1-start1
# ----> 6 print("CNN #3 Time: {:0.2f} minute".format(cnn3_time/60.0))
#
# NameError: name 'cnn3_time' is not defined

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn6.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN3 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn6_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 344ms/step
# --------------------------------------------
# -----------------CNN3 Summary---------------
# --------------------------------------------
# CNN Time: 13.81 minute
# F1 score: 0.6660606455236321
# Accuracy score: 0.7183333333333334
# Precision score: 0.7183333333333334
# Recall score: 0.7183333333333334

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn6.history['accuracy'])
plt.plot(history_cnn6.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN6 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn6_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# --------------------------------------------
# -----------------CNN6 Summary---------------
# --------------------------------------------
# CNN Time: 13.81 minute
# F1 score: 0.6660606455236321
# Accuracy score: 0.7183333333333334
# Precision score: 0.7183333333333334
# Recall score: 0.7183333333333334

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn6.history['accuracy'])
plt.plot(history_cnn6.history['val_accuracy'])
plt.title('CNN7 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn6 = history_cnn6.history
loss = hist_cnn6['loss']
val_loss = hist_cnn6['val_loss']
x = np.arange(250) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN6 Summary---------------")
print("-------------------------------------------")
print("CNN6 Trainning Time: {:0.2f} minute".format(cnn6_time/60.0))
print('Plotting confusion matrix')
plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN6 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred))
# Out:
# -------------------------------------------
# -----------------CNN6 Summary---------------
# -------------------------------------------
# CNN6 Trainning Time: 13.81 minute
# Plotting confusion matrix
# ------------------------------------------------------------
# ----------------- Classification Report CNN6 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        52
#          1.0       0.78      0.90      0.84        52
#          2.0       0.44      0.10      0.16        69
#          3.0       0.89      0.82      0.85        60
#          4.0       0.93      1.00      0.97        69
#          5.0       0.98      0.95      0.96        55
#          6.0       0.58      0.78      0.66        68
#          7.0       0.49      0.85      0.62        59
#          8.0       0.63      0.98      0.77        54
#          9.0       0.82      0.82      0.82        62
#
#     accuracy                           0.72       600
#    macro avg       0.65      0.72      0.67       600
# weighted avg       0.66      0.72      0.67       600

# %% [markdown]
# ---
#
#
# MODEL # 7
# ---

# %%
# Create CNN #4 model
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

cnn7 = Sequential()
    
cnn7.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn7.add(BatchNormalization())
cnn7.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn7.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
cnn7.add(BatchNormalization())

cnn7.add(Flatten())
cnn7.add(Dense(32,activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(Dropout(0.5))
cnn7.add(Dense(32,activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(Dropout(0.5))
cnn7.add(Dense(32,activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(Dropout(0.5))
cnn7.add(Dense(32,activation='relu'))
cnn7.add(BatchNormalization())
cnn7.add(Dropout(0.5))
cnn7.add(Dense(10))
cnn7.add(Activation('softmax'))

# %%
# Compile model
cnn7.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(),
    metrics=['accuracy'],
)

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn7 = cnn7.fit(train_esc, epochs=300, validation_data=valid_esc)
end1 = time.time()
cnn7_time = end1-start1
print("CNN #7 Time: {:0.2f} minute".format(cnn7_time/60.0))
# Out:
# Epoch 1/300
# 75/75 [==============================] - 11s 98ms/step - loss: 3.2630 - accuracy: 0.1075 - val_loss: 2.3032 - val_accuracy: 0.1150
# Epoch 2/300
# 75/75 [==============================] - 7s 87ms/step - loss: 2.9765 - accuracy: 0.1054 - val_loss: 2.3829 - val_accuracy: 0.0883
# Epoch 3/300
# 75/75 [==============================] - 8s 97ms/step - loss: 2.8086 - accuracy: 0.1021 - val_loss: 3.1227 - val_accuracy: 0.1250
# Epoch 4/300
# 75/75 [==============================] - 7s 89ms/step - loss: 2.6675 - accuracy: 0.1017 - val_loss: 2.5734 - val_accuracy: 0.1000
# Epoch 5/300
# 75/75 [==============================] - 8s 97ms/step - loss: 2.5857 - accuracy: 0.0946 - val_loss: 2.4010 - val_accuracy: 0.1150
# Epoch 6/300
# 75/75 [==============================] - 7s 90ms/step - loss: 2.5153 - accuracy: 0.1050 - val_loss: 2.3445 - val_accuracy: 0.0967
# Epoch 7/300
# 75/75 [==============================] - 7s 91ms/step - loss: 2.4570 - accuracy: 0.1054 - val_loss: 2.3483 - val_accuracy: 0.1083
# Epoch 8/300
# 75/75 [==============================] - 8s 95ms/step - loss: 2.4156 - accuracy: 0.1104 - val_loss: 2.3126 - val_accuracy: 0.1000
# Epoch 9/300
# 75/75 [==============================] - 7s 88ms/step - loss: 2.3732 - accuracy: 0.1129 - val_loss: 2.3018 - val_accuracy: 0.1167
# Epoch 10/300
# 75/75 [==============================] - 8s 96ms/step - loss: 2.3564 - accuracy: 0.1150 - val_loss: 2.2852 - val_accuracy: 0.1267
# 75/75 [==============================] - 8s 95ms/step - loss: 0.2935 - accuracy: 0.8633 - val_loss: 1.3484 - val_accuracy: 0.7750
# Epoch 284/300
# 75/75 [==============================] - 8s 97ms/step - loss: 0.2763 - accuracy: 0.8754 - val_loss: 1.4602 - val_accuracy: 0.7683
# Epoch 285/300
# 75/75 [==============================] - 7s 89ms/step - loss: 0.2687 - accuracy: 0.8737 - val_loss: 1.3625 - val_accuracy: 0.7683
# Epoch 286/300
# 75/75 [==============================] - 8s 100ms/step - loss: 0.3129 - accuracy: 0.8642 - val_loss: 1.4871 - val_accuracy: 0.7550
# Epoch 287/300
# 75/75 [==============================] - 7s 90ms/step - loss: 0.3111 - accuracy: 0.8592 - val_loss: 1.3161 - val_accuracy: 0.7633
# Epoch 288/300
# 75/75 [==============================] - 8s 97ms/step - loss: 0.3087 - accuracy: 0.8579 - val_loss: 1.3810 - val_accuracy: 0.7733
# Epoch 289/300
# 75/75 [==============================] - 7s 93ms/step - loss: 0.2952 - accuracy: 0.8637 - val_loss: 1.5316 - val_accuracy: 0.7500
# Epoch 290/300
# 75/75 [==============================] - 7s 90ms/step - loss: 0.3141 - accuracy: 0.8542 - val_loss: 1.4772 - val_accuracy: 0.7500
# Epoch 291/300
# 75/75 [==============================] - 8s 98ms/step - loss: 0.3153 - accuracy: 0.8546 - val_loss: 1.5652 - val_accuracy: 0.7550
# Epoch 292/300
# 75/75 [==============================] - 7s 89ms/step - loss: 0.2941 - accuracy: 0.8629 - val_loss: 1.3082 - val_accuracy: 0.7767
# Epoch 293/300
# 75/75 [==============================] - 8s 98ms/step - loss: 0.3341 - accuracy: 0.8608 - val_loss: 1.3556 - val_accuracy: 0.7817
# Epoch 294/300
# 75/75 [==============================] - 7s 90ms/step - loss: 0.2910 - accuracy: 0.8646 - val_loss: 1.3490 - val_accuracy: 0.7667
# Epoch 295/300
# 75/75 [==============================] - 8s 97ms/step - loss: 0.3109 - accuracy: 0.8621 - val_loss: 1.4537 - val_accuracy: 0.7700
# Epoch 296/300
# 75/75 [==============================] - 8s 94ms/step - loss: 0.2867 - accuracy: 0.8658 - val_loss: 1.4573 - val_accuracy: 0.7533
# Epoch 297/300
# 75/75 [==============================] - 7s 89ms/step - loss: 0.2948 - accuracy: 0.8608 - val_loss: 1.3820 - val_accuracy: 0.7700
# Epoch 298/300
# 75/75 [==============================] - 8s 98ms/step - loss: 0.2876 - accuracy: 0.8625 - val_loss: 1.3999 - val_accuracy: 0.7667
# Epoch 299/300
# 75/75 [==============================] - 7s 92ms/step - loss: 0.2596 - accuracy: 0.8687 - val_loss: 1.4010 - val_accuracy: 0.7583
# Epoch 300/300
# 75/75 [==============================] - 8s 98ms/step - loss: 0.2799 - accuracy: 0.8662 - val_loss: 1.4544 - val_accuracy: 0.7650
# CNN #7 Time: 37.82 minute

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn7.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN4 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn7_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# --------------------------------------------
# -----------------CNN4 Summary---------------
# --------------------------------------------
# CNN Time: 37.82 minute
# F1 score: 0.7302101388284409
# Accuracy score: 0.765
# Precision score: 0.765
# Recall score: 0.765

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn7.history['accuracy'])
plt.plot(history_cnn7.history['val_accuracy'])
plt.title('CNN7 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn7 = history_cnn7.history
loss = hist_cnn7['loss']
val_loss = hist_cnn7['val_loss']
x = np.arange(300) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN7 Summary---------------")
print("-------------------------------------------")
print("CNN7 Trainning Time: {:0.2f} minute".format(cnn4_time/60.0))
print('Plotting confusion matrix')
plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN2 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred))
# Out:
# -------------------------------------------
# -----------------CNN7 Summary---------------
# -------------------------------------------
# CNN7 Trainning Time: 25.40 minute
# Plotting confusion matrix
# ------------------------------------------------------------
# ----------------- Classification Report CNN2 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.92      0.90        52
#          1.0       0.80      0.87      0.83        52
#          2.0       0.00      0.00      0.00        69
#          3.0       0.92      0.73      0.81        60
#          4.0       0.93      0.94      0.94        69
#          5.0       0.89      0.85      0.87        55
#          6.0       0.74      0.79      0.77        68
#          7.0       0.92      0.80      0.85        59
#          8.0       0.43      0.98      0.60        54
#          9.0       0.78      0.90      0.84        62
#
#     accuracy                           0.77       600
#    macro avg       0.73      0.78      0.74       600
# weighted avg       0.72      0.77      0.73       600
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ---
#
#
#
#
# ```
# # This is formatted as code
# ```
#
# ## **MODEL  #8 : CNN2-BATCH
#
# ---

# %%
# Create CNN #4 model
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

cnn8 = Sequential()
    
cnn8.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(32,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(64,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn8.add(BatchNormalization())
cnn8.add(Conv2D(128,(3,3),padding='same',activation='relu'))
cnn8.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
cnn8.add(BatchNormalization())

cnn8.add(Flatten())
cnn8.add(Dense(32,activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(Dropout(0.5))
cnn8.add(Dense(32,activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(Dropout(0.5))
cnn8.add(Dense(32,activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(Dropout(0.5))
cnn8.add(Dense(32,activation='relu'))
cnn8.add(BatchNormalization())
cnn8.add(Dropout(0.5))
cnn8.add(Dense(10))
cnn8.add(Activation('softmax'))


cnn8.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  batch_normalization (BatchN  (None, 256, 256, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  batch_normalization_1 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  batch_normalization_2 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        9248
#
#  batch_normalization_4 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  batch_normalization_9 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_10 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  batch_normalization_11 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 128)         147584
#
#  batch_normalization_12 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  batch_normalization_13 (Bat  (None, 2, 2, 128)        512
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  batch_normalization_14 (Bat  (None, 1, 1, 128)        512
#  chNormalization)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  batch_normalization_15 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_16 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_17 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  batch_normalization_18 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 10)                330
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 451,146
# Trainable params: 448,778
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
# Compile model
cnn8.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(),
    metrics=['accuracy'],
)

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn8 = cnn8.fit(train_esc, epochs=300, validation_data=valid_esc)
end1 = time.time()
cnn8_time = end1-start1
print("CNN #7 Time: {:0.2f} minute".format(cnn8_time/60.0))
# Out:
# Epoch 1/300
# 75/75 [==============================] - 11s 44ms/step - loss: 3.1097 - accuracy: 0.1117 - val_loss: 2.3652 - val_accuracy: 0.0867
# Epoch 2/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.8802 - accuracy: 0.1121 - val_loss: 2.4694 - val_accuracy: 0.1033
# Epoch 3/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.7952 - accuracy: 0.0988 - val_loss: 2.4752 - val_accuracy: 0.0733
# Epoch 4/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.6663 - accuracy: 0.1008 - val_loss: 2.3891 - val_accuracy: 0.0917
# Epoch 5/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.5749 - accuracy: 0.1079 - val_loss: 2.4147 - val_accuracy: 0.0800
# Epoch 6/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.5208 - accuracy: 0.0971 - val_loss: 2.3118 - val_accuracy: 0.1283
# Epoch 7/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.4619 - accuracy: 0.1096 - val_loss: 2.2922 - val_accuracy: 0.1217
# Epoch 8/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.4094 - accuracy: 0.1083 - val_loss: 2.2978 - val_accuracy: 0.1033
# Epoch 9/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.4051 - accuracy: 0.1029 - val_loss: 2.3108 - val_accuracy: 0.1083
# Epoch 10/300
# 75/75 [==============================] - 3s 38ms/step - loss: 2.3497 - accuracy: 0.1067 - val_loss: 2.2880 - val_accuracy: 0.1617
# Epoch 11/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.3269 - accuracy: 0.1250 - val_loss: 2.2685 - val_accuracy: 0.1550
# Epoch 12/300
# 75/75 [==============================] - 3s 38ms/step - loss: 2.3268 - accuracy: 0.1146 - val_loss: 2.2325 - val_accuracy: 0.1550
# Epoch 13/300
# 75/75 [==============================] - 3s 40ms/step - loss: 2.2900 - accuracy: 0.1371 - val_loss: 2.1974 - val_accuracy: 0.1817
# Epoch 14/300
# 75/75 [==============================] - 3s 39ms/step - loss: 2.2644 - accuracy: 0.1446 - val_loss: 2.1876 - val_accuracy: 0.2083
# Epoch 15/300
# Epoch 288/300
# 75/75 [==============================] - 3s 38ms/step - loss: 0.2776 - accuracy: 0.8608 - val_loss: 1.4943 - val_accuracy: 0.7633
# Epoch 289/300
# 75/75 [==============================] - 3s 39ms/step - loss: 0.2833 - accuracy: 0.8554 - val_loss: 1.2773 - val_accuracy: 0.7917
# Epoch 290/300
# 75/75 [==============================] - 3s 40ms/step - loss: 0.2711 - accuracy: 0.8562 - val_loss: 1.2957 - val_accuracy: 0.7733
# Epoch 291/300
# 75/75 [==============================] - 3s 39ms/step - loss: 0.2579 - accuracy: 0.8717 - val_loss: 1.3371 - val_accuracy: 0.7800
# Epoch 292/300
# 75/75 [==============================] - 3s 39ms/step - loss: 0.2643 - accuracy: 0.8637 - val_loss: 1.5132 - val_accuracy: 0.7517
# Epoch 293/300
# 75/75 [==============================] - 3s 38ms/step - loss: 0.2869 - accuracy: 0.8708 - val_loss: 1.2480 - val_accuracy: 0.7867
# Epoch 294/300
# 75/75 [==============================] - 3s 40ms/step - loss: 0.2877 - accuracy: 0.8496 - val_loss: 1.2839 - val_accuracy: 0.7850
# Epoch 295/300
# 75/75 [==============================] - 3s 38ms/step - loss: 0.2769 - accuracy: 0.8637 - val_loss: 1.4097 - val_accuracy: 0.7867
# Epoch 296/300
# 75/75 [==============================] - 3s 38ms/step - loss: 0.3014 - accuracy: 0.8562 - val_loss: 1.4274 - val_accuracy: 0.7667
# Epoch 297/300
# 75/75 [==============================] - 3s 39ms/step - loss: 0.2770 - accuracy: 0.8554 - val_loss: 1.4813 - val_accuracy: 0.7767
# Epoch 298/300
# 75/75 [==============================] - 3s 40ms/step - loss: 0.2954 - accuracy: 0.8567 - val_loss: 1.6139 - val_accuracy: 0.7650
# Epoch 299/300
# 75/75 [==============================] - 3s 39ms/step - loss: 0.2565 - accuracy: 0.8658 - val_loss: 1.4438 - val_accuracy: 0.7783
# Epoch 300/300
# 75/75 [==============================] - 3s 38ms/step - loss: 0.3040 - accuracy: 0.8596 - val_loss: 1.3426 - val_accuracy: 0.7850
# CNN #7 Time: 15.89 minute

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn8.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
# Out:
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 332ms/step

# %%
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN8 Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn8_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# --------------------------------------------
# -----------------CNN8 Summary---------------
# --------------------------------------------
# CNN Time: 15.89 minute
# F1 score: 0.759990055713271
# Accuracy score: 0.785
# Precision score: 0.785
# Recall score: 0.785

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn8.history['accuracy'])
plt.plot(history_cnn8.history['val_accuracy'])
plt.title('CNN8 accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn8= history_cnn8.history
loss = hist_cnn8['loss']
val_loss = hist_cnn8['val_loss']
x = np.arange(300) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN8 Summary---------------")
print("-------------------------------------------")
print("CNN7 Trainning Time: {:0.2f} minute".format(cnn8_time/60.0))
print('Plotting confusion matrix')
plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN8 ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred ,target_names=labelNames))
# Out:
# -------------------------------------------
# -----------------CNN8 Summary---------------
# -------------------------------------------
# CNN7 Trainning Time: 15.89 minute
# Plotting confusion matrix
# ------------------------------------------------------------
# ----------------- Classification Report CNN8 ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        bird1       0.00      0.00      0.00        52
#       bird10       0.79      0.94      0.86        52
#        bird2       0.78      0.74      0.76        69
#        bird3       0.85      0.83      0.84        60
#        bird4       0.96      0.93      0.94        69
#        bird5       0.95      0.95      0.95        55
#        bird6       0.85      0.85      0.85        68
#        bird7       0.45      0.88      0.60        59
#        bird8       0.88      0.91      0.89        54
#        bird9       0.88      0.74      0.81        62
#
#     accuracy                           0.79       600
#    macro avg       0.74      0.78      0.75       600
# weighted avg       0.75      0.79      0.76       600

# %% [markdown]
# ---
#
#
# ## MODELO 4.1
#
#
# ---

# %%
# Create CNN #4 model
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

cnn41 = Sequential()
    
cnn41.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(32,(3,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(32,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(64,(3,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(64,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(3,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(128,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(3,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))
cnn41.add(BatchNormalization())

cnn41.add(Flatten())
cnn41.add(Dense(32,activation='relu'))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(10))
cnn41.add(Activation('softmax'))

# %%
# Compile model
learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
cnn41.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
    metrics=['accuracy'],
)


#learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
#model_DenseNet.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

# %%
# Epoch 194/200
# 75/75 [==============================] - 3s 37ms/step - loss: 2.6352 - accuracy: 0.1513 - val_loss: 2.0587 - val_accuracy: 0.2700
# Epoch 195/200
# 75/75 [==============================] - 3s 36ms/step - loss: 2.6444 - accuracy: 0.1587 - val_loss: 2.0570 - val_accuracy: 0.2683
# Epoch 196/200
# 75/75 [==============================] - 3s 36ms/step - loss: 2.6740 - accuracy: 0.1587 - val_loss: 2.0596 - val_accuracy: 0.2600
# Epoch 197/200
# 75/75 [==============================] - 3s 36ms/step - loss: 2.6703 - accuracy: 0.1546 - val_loss: 2.0589 - val_accuracy: 0.2550
# Epoch 198/200
# 75/75 [==============================] - 3s 39ms/step - loss: 2.6110 - accuracy: 0.1612 - val_loss: 2.0628 - val_accuracy: 0.2600
# Epoch 199/200
# 75/75 [==============================] - 3s 36ms/step - loss: 2.6437 - accuracy: 0.1625 - val_loss: 2.0621 - val_accuracy: 0.2633
# Epoch 200/200
# 75/75 [==============================] - 3s 36ms/step - loss: 2.5858 - accuracy: 0.1729 - val_loss: 2.0635 - val_accuracy: 0.2667
# CNN #41 Time: 10.12 minute

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn41.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn41_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-950b5e8661c3> in <cell line: 7>()
#       5 from sklearn.metrics import confusion_matrix
#       6 from sklearn import metrics
# ----> 7 yPred = np.array([])
#       8 yTest =  np.array([])
#       9 for x, y in valid_esc:
#
# NameError: name 'np' is not defined

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn41.history['accuracy'])
plt.plot(history_cnn41.history['val_accuracy'])
plt.title('CNN accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn41 = history_cnn41.history
loss = hist_cnn41['loss']
val_loss = hist_cnn41['val_loss']
x = np.arange(350) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn41.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
  
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN Summary---------------")
print("-------------------------------------------")
print("CNN2 Trainning Time: {:0.2f} minute".format(cnn41_time/60.0))
print('Plotting confusion matrix')
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# -------------------------------------------
# -----------------CNN Summary---------------
# -------------------------------------------
# CNN2 Trainning Time: 21.47 minute
# Plotting confusion matrix

# %%
plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred, target_names = labelNames))
# Out:
# ------------------------------------------------------------
# ----------------- Classification Report CNN ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        bird1       0.52      0.98      0.68        52
#       bird10       0.87      0.79      0.83        52
#        bird2       0.82      0.65      0.73        69
#        bird3       0.92      0.77      0.84        60
#        bird4       0.96      0.97      0.96        69
#        bird5       0.96      0.93      0.94        55
#        bird6       0.78      0.84      0.81        68
#        bird7       0.67      0.10      0.18        59
#        bird8       0.78      0.98      0.87        54
#        bird9       0.72      0.89      0.80        62
#
#     accuracy                           0.79       600
#    macro avg       0.80      0.79      0.76       600
# weighted avg       0.80      0.79      0.76       600

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ## MODEL : ASYM

# %%
# Create LEALY REALUUUUUUUUUUUUUUUUUUUUUUUUU
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU

cnn41 = Sequential()
    
cnn41.add(Conv2D(16,(3,3),padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

cnn41.add(BatchNormalization())
cnn41.add(Conv2D(32,(1,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(1,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(32,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn41.add(BatchNormalization())
cnn41.add(Conv2D(64,(1,3),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(1,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(64,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(1,2),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(1,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(128,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(1,2),padding='same',activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(MaxPooling2D(pool_size=(1,2),strides=2,padding = 'same'))
cnn41.add(BatchNormalization())

cnn41.add(Flatten())
cnn41.add(Dense(32,activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(32,activation='linear'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.5))
cnn41.add(Dense(10))
cnn41.add(Activation('softmax'))

# %%
# Compile model
from tensorflow.keras.optimizers import Adam , SGD, RMSprop
from tensorflow.keras import optimizers
learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
cnn41.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
    metrics=['accuracy'],
)


#learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
#model_DenseNet.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn41 = cnn41.fit(train_esc, epochs=50, validation_data=valid_esc)
end1 = time.time()
cnn41_time = end1-start1
print("CNN #41 Time: {:0.2f} minute".format(cnn41_time/60.0))
# Out:
# Epoch 1/50
# 53/75 [====================>.........] - ETA: 0s - loss: 3.5064 - accuracy: 0.1032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-45405cd75cf5> in <cell line: 4>()
#       2 start1 = time.time()
#       3 # Train model for 10 epochs, capture the history
# ----> 4 history_cnn41 = cnn41.fit(train_esc, epochs=50, validation_data=valid_esc)
#       5 end1 = time.time()
#       6 cnn41_time = end1-start1
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ## CNN3-LEAKY RELU
#
# ---

# %%
#cnn41.add(LeakyReLU(alpha=0.05))
# Create CNN #4 model
# Accelerate Learning of Deep Neural Networks With Batch Normalization
# Use Before or After the Activation Function
# Some reported experiments suggest better performance when adding the batch normalization layer after the activation function of the previous laye
# https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/
#
#from extra_keras_datasets import kmnist
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU

cnn41 = Sequential()
    
cnn41.add(Conv2D(32,(7,7),strides=2,padding='same',input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,NO_CHANNELS),activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(32,(7,7),strides=2,padding='same',activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(32,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(64,(5,5),strides=2,padding='same',activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(64,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(5,5),strides=2,padding='same',activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
#cnn41.add(Conv2D(128,(3,3),padding='same',activation='relu'))
#cnn41.add(BatchNormalization())
#cnn41.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

#cnn41.add(BatchNormalization())
cnn41.add(Conv2D(128,(3,3),strides=2,padding='same',activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(MaxPooling2D(pool_size=(3,3),strides=2,padding = 'same'))
cnn41.add(BatchNormalization())

cnn41.add(Flatten())
cnn41.add(Dense(32,activation='relu'))
cnn41.add(LeakyReLU(alpha=0.06))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.6))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.6))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.6))
cnn41.add(Dense(32,activation='relu'))
cnn41.add(LeakyReLU(alpha=0.05))
cnn41.add(BatchNormalization())
cnn41.add(Dropout(0.6))
cnn41.add(Dense(10))
cnn41.add(Activation('softmax'))

cnn41.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_85 (Conv2D)          (None, 128, 128, 32)      4736
#
#  leaky_re_lu_106 (LeakyReLU)  (None, 128, 128, 32)     0
#
#  batch_normalization_193 (Ba  (None, 128, 128, 32)     128
#  tchNormalization)
#
#  max_pooling2d_84 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 32, 32, 32)        50208
#
#  leaky_re_lu_107 (LeakyReLU)  (None, 32, 32, 32)       0
#
#  batch_normalization_194 (Ba  (None, 32, 32, 32)       128
#  tchNormalization)
#
#  max_pooling2d_85 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 8, 8, 64)          51264
#
#  leaky_re_lu_108 (LeakyReLU)  (None, 8, 8, 64)         0
#
#  batch_normalization_195 (Ba  (None, 8, 8, 64)         256
#  tchNormalization)
#
#  max_pooling2d_86 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 2, 2, 128)         204928
#
#  leaky_re_lu_109 (LeakyReLU)  (None, 2, 2, 128)        0
#
#  batch_normalization_196 (Ba  (None, 2, 2, 128)        512
#  tchNormalization)
#
#  max_pooling2d_87 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  conv2d_89 (Conv2D)          (None, 1, 1, 128)         147584
#
#  leaky_re_lu_110 (LeakyReLU)  (None, 1, 1, 128)        0
#
#  max_pooling2d_88 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  batch_normalization_197 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  flatten_15 (Flatten)        (None, 128)               0
#
#  dense_75 (Dense)            (None, 32)                4128
#
#  leaky_re_lu_111 (LeakyReLU)  (None, 32)               0
#
#  batch_normalization_198 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dropout_60 (Dropout)        (None, 32)                0
#
#  dense_76 (Dense)            (None, 32)                1056
#
#  leaky_re_lu_112 (LeakyReLU)  (None, 32)               0
#
#  batch_normalization_199 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dropout_61 (Dropout)        (None, 32)                0
#
#  dense_77 (Dense)            (None, 32)                1056
#
#  leaky_re_lu_113 (LeakyReLU)  (None, 32)               0
#
#  batch_normalization_200 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dropout_62 (Dropout)        (None, 32)                0
#
#  dense_78 (Dense)            (None, 32)                1056
#
#  leaky_re_lu_114 (LeakyReLU)  (None, 32)               0
#
#  batch_normalization_201 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dropout_63 (Dropout)        (None, 32)                0
#
#  dense_79 (Dense)            (None, 10)                330
#
#  activation_15 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 468,394
# Trainable params: 467,370
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# Compile model
from tensorflow.keras.optimizers import Adam , SGD, RMSprop
from tensorflow.keras import optimizers
learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
INIT_LR = 1e-3
cnn41.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=INIT_LR),
    metrics=['accuracy'],
)
#import tensorflow as tf 


#cnn41.compile(
#     loss='sparse_categorical_crossentropy',
#      optimizer=tf.keras.optimizers.legacy.Adagrad(learning_rate=INIT_LR, decay=INIT_LR / 100)
#      ,metrics=['accuracy']
#)

#learning_rate = optimizers.schedules.PolynomialDecay(1e-5,10000,1e-6,power=0.4)
#cnn41.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

# %%
# Train model for 10 epochs, capture the history
start1 = time.time()
# Train model for 10 epochs, capture the history
history_cnn41 = cnn41.fit(train_esc, epochs=350, validation_data=valid_esc)
end1 = time.time()
cnn41_time = end1-start1
print("CNN #41 Time: {:0.2f} minute".format(cnn41_time/60.0))
# Out:
# Epoch 1/350
# 75/75 [==============================] - 8s 35ms/step - loss: 3.3663 - accuracy: 0.1042 - val_loss: 2.3271 - val_accuracy: 0.0983
# Epoch 2/350
# 75/75 [==============================] - 3s 35ms/step - loss: 3.1295 - accuracy: 0.0996 - val_loss: 2.3455 - val_accuracy: 0.0983
# Epoch 3/350
# 75/75 [==============================] - 3s 35ms/step - loss: 2.9353 - accuracy: 0.0988 - val_loss: 2.3252 - val_accuracy: 0.1017
# Epoch 4/350
# 75/75 [==============================] - 3s 35ms/step - loss: 2.7550 - accuracy: 0.1058 - val_loss: 2.3007 - val_accuracy: 0.1133
# Epoch 5/350
# 75/75 [==============================] - 3s 35ms/step - loss: 2.6230 - accuracy: 0.1142 - val_loss: 2.3232 - val_accuracy: 0.0983
# Epoch 6/350
# 75/75 [==============================] - 3s 37ms/step - loss: 2.5865 - accuracy: 0.0958 - val_loss: 2.3274 - val_accuracy: 0.0867
# Epoch 7/350
# 75/75 [==============================] - 3s 35ms/step - loss: 2.4940 - accuracy: 0.0983 - val_loss: 2.3311 - val_accuracy: 0.1017
# Epoch 339/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5972 - accuracy: 0.7471 - val_loss: 1.4229 - val_accuracy: 0.6867
# Epoch 340/350
# 75/75 [==============================] - 3s 36ms/step - loss: 0.5706 - accuracy: 0.7325 - val_loss: 1.3645 - val_accuracy: 0.6900
# Epoch 341/350
# 75/75 [==============================] - 3s 36ms/step - loss: 0.5859 - accuracy: 0.7346 - val_loss: 1.3605 - val_accuracy: 0.7067
# Epoch 342/350
# 75/75 [==============================] - 3s 37ms/step - loss: 0.5562 - accuracy: 0.7396 - val_loss: 1.3493 - val_accuracy: 0.6667
# Epoch 343/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5801 - accuracy: 0.7383 - val_loss: 1.3499 - val_accuracy: 0.6683
# Epoch 344/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5739 - accuracy: 0.7533 - val_loss: 1.5708 - val_accuracy: 0.6667
# Epoch 345/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5678 - accuracy: 0.7450 - val_loss: 1.3715 - val_accuracy: 0.6900
# Epoch 346/350
# 75/75 [==============================] - 3s 37ms/step - loss: 0.5832 - accuracy: 0.7450 - val_loss: 1.2743 - val_accuracy: 0.7050
# Epoch 347/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.6048 - accuracy: 0.7329 - val_loss: 1.2566 - val_accuracy: 0.7050
# Epoch 348/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5528 - accuracy: 0.7317 - val_loss: 1.2972 - val_accuracy: 0.7017
# Epoch 349/350
# 75/75 [==============================] - 3s 35ms/step - loss: 0.5666 - accuracy: 0.7400 - val_loss: 1.2944 - val_accuracy: 0.7050
# Epoch 350/350
# 75/75 [==============================] - 3s 34ms/step - loss: 0.5980 - accuracy: 0.7358 - val_loss: 1.3189 - val_accuracy: 0.7017
# CNN #41 Time: 17.12 minute

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn41.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)

cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_precision = metrics.precision_score(yTest, yPred,average="micro" )
cnn_recall = metrics.recall_score (yTest, yPred,average="micro" )
print("--------------------------------------------")
print("-----------------CNN Summary---------------")
print("--------------------------------------------")
print("CNN Time: {:0.2f} minute".format(cnn41_time/60.0))
print("F1 score: {}".format(cnn_f1))
print("Accuracy score: {}".format(cnn_accuracy))
print("Precision score: {}".format(cnn_precision))
print("Recall score: {}".format(cnn_recall))
# Out:
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 244ms/step
# --------------------------------------------
# -----------------CNN Summary---------------
# --------------------------------------------
# CNN Time: 17.12 minute
# F1 score: 0.6945499406039656
# Accuracy score: 0.7016666666666667
# Precision score: 0.7016666666666667
# Recall score: 0.7016666666666667

# %%
##---------------------------------------------
##-------------- Accuracy evolution -----------
##---------------------------------------------
from matplotlib import pyplot as plt
plt.plot(history_cnn41.history['accuracy'])
plt.plot(history_cnn41.history['val_accuracy'])
plt.title('CNN accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
##---------------------------------------------
##-------------- Loss evolution -----------
##---------------------------------------------
hist_cnn41 = history_cnn41.history
loss = hist_cnn41['loss']
val_loss = hist_cnn41['val_loss']
x = np.arange(350) + 1

plt.title("Loss function")
plt.plot(x, loss, label="Train loss")
plt.plot(x, val_loss, label="Validation loss")
plt.legend()
plt.show()

# %%
##---------------------------------------------
##------------ Classification Report ----------
##---------------------------------------------
# CNN report and analysis
# es necesario que el  predict y el ytest esten en el mismo for, con eso garantizamos que ambos trabajen con el mismo conjunto de datos
from sklearn.metrics import confusion_matrix
from sklearn import metrics
yPred = np.array([])
yTest =  np.array([])
for x, y in valid_esc:
  yPred = np.concatenate([yPred, np.argmax(cnn41.predict(x), axis = -1)])
  yTest = np.concatenate([yTest, y.numpy()])  # no es necesario el argmax  aqui np.argmax(y.numpy(), axis=-1)
  
import numpy as np
#yPred = np.argmax(pred_Y, axis=1)
#yTest = valid_label  #np.argmax(test_label, axis=1) no es necesario por que nuestro test_label ya tiene la forma
labelNames =valid_dataset.class_names
cnn_f1 = metrics.f1_score(yTest, yPred, average= "weighted")
cnn_accuracy = metrics.accuracy_score(yTest, yPred)
cnn_cm = metrics.confusion_matrix(yTest, yPred)
print("-------------------------------------------")
print("-----------------CNN Summary---------------")
print("-------------------------------------------")
print("CNN2 Trainning Time: {:0.2f} minute".format(cnn41_time/60.0))
print('Plotting confusion matrix')
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# -------------------------------------------
# -----------------CNN Summary---------------
# -------------------------------------------
# CNN2 Trainning Time: 17.12 minute
# Plotting confusion matrix

# %%
plt.figure()
plot_confusion_matrix(cnn_cm, labelNames)
plt.show()
print("------------------------------------------------------------")
print("----------------- Classification Report CNN ---------------")
print("------------------------------------------------------------")
print(metrics.classification_report(yTest, yPred, target_names = labelNames))
# Out:
# ------------------------------------------------------------
# ----------------- Classification Report CNN ---------------
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#        bird1       0.87      0.88      0.88        52
#       bird10       0.82      0.87      0.84        52
#        bird2       0.40      0.48      0.44        69
#        bird3       0.80      0.73      0.77        60
#        bird4       0.97      0.90      0.93        69
#        bird5       0.89      0.91      0.90        55
#        bird6       0.48      0.21      0.29        68
#        bird7       0.76      0.81      0.79        59
#        bird8       0.44      0.93      0.60        54
#        bird9       0.97      0.47      0.63        62
#
#     accuracy                           0.70       600
#    macro avg       0.74      0.72      0.71       600
# weighted avg       0.74      0.70      0.69       600
